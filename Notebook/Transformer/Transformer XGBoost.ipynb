# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import glob
import os
from datetime import datetime as dt
from scipy.stats import skew, kurtosis
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (classification_report, confusion_matrix, ConfusionMatrixDisplay,
                             accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, roc_curve)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Flatten, Layer
from tensorflow.keras import backend as K
from scikeras.wrappers import KerasClassifier
import optuna
from optuna.integration import TFKerasPruningCallback, XGBoostPruningCallback
import joblib
import warnings
warnings.filterwarnings('ignore')
from xgboost.callback import EarlyStopping

print("✅ Libraries imported successfully")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# ✅ Libraries imported successfully
# TensorFlow version: 2.20.0

# %% [markdown]
# # Load MIMIC Perform AF Dataset
#
# **Dataset info:**
# - AF: 16 pasien (mimic_perform_af_001 - mimic_perform_af_016)
# - Non-AF: 16 pasien (mimic_perform_non_af_001 - mimic_perform_non_af_016)
# - Sampling Rate: 125Hz
# - Duration: ~20 menit per pasien (150,000 samples)
# - Columns: Time, PPG, ECG, resp

# %%
# Path configuration
current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..', '..'))

af_folder = os.path.join(project_root, 'Data', 'af')
nonaf_folder = os.path.join(project_root, 'Data', 'non-af')

# List files - Balance: AF only up to patient 16
af_files_all = sorted(glob.glob(os.path.join(af_folder, '*_data.csv')))
af_files = af_files_all[:16]
nonaf_files = sorted(glob.glob(os.path.join(nonaf_folder, '*_data.csv')))

print("="*60)
print("DATASET: MIMIC Perform AF (Balanced)")
print("="*60)
print(f"\n📁 AF Folder: {af_folder}")
print(f"   Patients: {len(af_files)}")
print(f"\n📁 Non-AF Folder: {nonaf_folder}")
print(f"   Patients: {len(nonaf_files)}")
print(f"\n📊 Total Patients: {len(af_files) + len(nonaf_files)}")
# Out:
# ============================================================
# DATASET: MIMIC Perform AF (Balanced)
# ============================================================
#
# 📁 AF Folder: c:\Users\Lenovo\Documents\GitHub\FP_MLxDM\Data\af
#    Patients: 16
#
# 📁 Non-AF Folder: c:\Users\Lenovo\Documents\GitHub\FP_MLxDM\Data\non-af
#    Patients: 16
#
# 📊 Total Patients: 32

# %% [markdown]
# ## Train-Test Split (Sesuai Jurnal: 65% Train, 35% Test)
#
# Split berdasarkan pasien untuk menghindari data leakage

# %%
# Split 65% train, 35% test (sesuai jurnal)
# Split per kelas untuk menjaga proporsi

np.random.seed(42)

# Shuffle files
af_files_shuffled = np.random.permutation(af_files).tolist()
nonaf_files_shuffled = np.random.permutation(nonaf_files).tolist()

# Split AF: 65% train, 35% test
n_af_train = int(len(af_files) * 0.65)
train_af = af_files_shuffled[:n_af_train]
test_af = af_files_shuffled[n_af_train:]

# Split Non-AF: 65% train, 35% test
n_nonaf_train = int(len(nonaf_files) * 0.65)
train_nonaf = nonaf_files_shuffled[:n_nonaf_train]
test_nonaf = nonaf_files_shuffled[n_nonaf_train:]

print("="*60)
print("DATA SPLIT (Sesuai Jurnal: 65% Train, 35% Test)")
print("="*60)
print(f"\n📊 AF Split:")
print(f"   Train: {len(train_af)} patients")
print(f"   Test: {len(test_af)} patients")
print(f"\n📊 Non-AF Split:")
print(f"   Train: {len(train_nonaf)} patients")
print(f"   Test: {len(test_nonaf)} patients")
print(f"\n📊 Total:")
print(f"   Train: {len(train_af) + len(train_nonaf)} patients")
print(f"   Test: {len(test_af) + len(test_nonaf)} patients")
# Out:
# ============================================================
# DATA SPLIT (Sesuai Jurnal: 65% Train, 35% Test)
# ============================================================
#
# 📊 AF Split:
#    Train: 10 patients
#    Test: 6 patients
#
# 📊 Non-AF Split:
#    Train: 10 patients
#    Test: 6 patients
#
# 📊 Total:
#    Train: 20 patients
#    Test: 12 patients

# %% [markdown]
# ## Load Data Function

# %%
def load_patient_data(file_path, max_samples=150000):
    """
    Load ECG data dari file CSV.
    """
    df = pd.read_csv(file_path)
    
    # Limit samples
    if len(df) > max_samples:
        df = df.iloc[:max_samples]
    
    # Get ECG column
    ecg = df['ECG'].values
    
    # Handle NaN
    if np.any(np.isnan(ecg)):
        ecg = pd.Series(ecg).interpolate().values
    
    return ecg

print("✅ Load function defined")
# Out:
# ✅ Load function defined

# %% [markdown]
# ## Feature Extraction (Sesuai Jurnal)
#
# 5 fitur statistik per window:
# 1. Skewness
# 2. Kurtosis
# 3. Minimum
# 4. Maximum
# 5. Standard Deviation

# %%
# Parameters
SAMPLING_RATE = 125  # Hz
WINDOW_SIZE = SAMPLING_RATE  # 1 second = 125 samples
SEQUENCE_LENGTH = 10  # 10 windows = 10 seconds context

def extract_statistical_features(window):
    """
    Extract 5 statistical features (sesuai jurnal):
    Skewness, Kurtosis, Min, Max, STD
    """
    return np.array([
        skew(window),
        kurtosis(window),
        np.min(window),
        np.max(window),
        np.std(window)
    ])

def extract_features_from_signal(ecg_signal, window_size=125):
    """
    Extract features dari ECG signal.
    """
    n_windows = len(ecg_signal) // window_size
    features = []
    
    for i in range(n_windows):
        start = i * window_size
        end = start + window_size
        window = ecg_signal[start:end]
        features.append(extract_statistical_features(window))
    
    return np.array(features)

print(f"📊 Parameters:")
print(f"   Sampling Rate: {SAMPLING_RATE} Hz")
print(f"   Window Size: {WINDOW_SIZE} samples (1 second)")
print(f"   Sequence Length: {SEQUENCE_LENGTH} windows")
print(f"   Features: 5 (Skewness, Kurtosis, Min, Max, STD)")
# Out:
# 📊 Parameters:
#    Sampling Rate: 125 Hz
#    Window Size: 125 samples (1 second)
#    Sequence Length: 10 windows
#    Features: 5 (Skewness, Kurtosis, Min, Max, STD)

# %% [markdown]
# ## Load and Extract Features

# %%
def load_and_extract(files, label, desc=""):
    """
    Load files dan extract features.
    """
    all_features = []
    all_labels = []
    
    for f in files:
        patient_id = os.path.basename(f).replace('_data.csv', '')
        print(f"   Loading {patient_id}...", end=" ")
        
        # Load ECG
        ecg = load_patient_data(f)
        
        # Extract features
        features = extract_features_from_signal(ecg, WINDOW_SIZE)
        labels = np.full(len(features), label)
        
        all_features.append(features)
        all_labels.append(labels)
        
        print(f"{len(features)} windows")
    
    return np.vstack(all_features), np.concatenate(all_labels)

# Load Training Data
print("="*60)
print("LOADING TRAINING DATA")
print("="*60)

print("\n📥 Loading AF patients (Train)...")
X_train_af, y_train_af = load_and_extract(train_af, label=1)

print("\n📥 Loading Non-AF patients (Train)...")
X_train_nonaf, y_train_nonaf = load_and_extract(train_nonaf, label=0)

# Combine training data
X_train = np.vstack([X_train_af, X_train_nonaf])
y_train = np.concatenate([y_train_af, y_train_nonaf])

print("\n" + "="*60)
print("LOADING TEST DATA")
print("="*60)

print("\n📥 Loading AF patients (Test)...")
X_test_af, y_test_af = load_and_extract(test_af, label=1)

print("\n📥 Loading Non-AF patients (Test)...")
X_test_nonaf, y_test_nonaf = load_and_extract(test_nonaf, label=0)

# Combine test data
X_test = np.vstack([X_test_af, X_test_nonaf])
y_test = np.concatenate([y_test_af, y_test_nonaf])

print("\n" + "="*60)
print("✅ DATA LOADED")
print("="*60)
print(f"\n📊 Training Data:")
print(f"   Samples: {len(X_train)}")
print(f"   AF: {np.sum(y_train==1)} ({np.sum(y_train==1)/len(y_train)*100:.1f}%)")
print(f"   Non-AF: {np.sum(y_train==0)} ({np.sum(y_train==0)/len(y_train)*100:.1f}%)")
print(f"\n📊 Test Data:")
print(f"   Samples: {len(X_test)}")
print(f"   AF: {np.sum(y_test==1)} ({np.sum(y_test==1)/len(y_test)*100:.1f}%)")
print(f"   Non-AF: {np.sum(y_test==0)} ({np.sum(y_test==0)/len(y_test)*100:.1f}%)")
# Out:
# ============================================================
# LOADING TRAINING DATA
# ============================================================
#
# 📥 Loading AF patients (Train)...
#    Loading mimic_perform_af_001... 1200 windows
#    Loading mimic_perform_af_002... 1200 windows
#    Loading mimic_perform_af_006... 1200 windows
#    Loading mimic_perform_af_015... 1200 windows
#    Loading mimic_perform_af_014... 1200 windows
#    Loading mimic_perform_af_012... 1200 windows
#    Loading mimic_perform_af_009... 1200 windows
#    Loading mimic_perform_af_010... 1200 windows
#    Loading mimic_perform_af_003... 1200 windows
#    Loading mimic_perform_af_016... 1200 windows
#
# 📥 Loading Non-AF patients (Train)...
#    Loading mimic_perform_non_af_007... 1200 windows
#    Loading mimic_perform_non_af_003... 1200 windows
#    Loading mimic_perform_non_af_009... 1200 windows
#    Loading mimic_perform_non_af_014... 1200 windows
#    Loading mimic_perform_non_af_010... 1200 windows
#    Loading mimic_perform_non_af_013... 1200 windows
#    Loading mimic_perform_non_af_011... 1200 windows
#    Loading mimic_perform_non_af_004... 1200 windows
#    Loading mimic_perform_non_af_001... 1200 windows
#    Loading mimic_perform_non_af_016... 1200 windows
#
# ============================================================
# LOADING TEST DATA
# ============================================================
#
# 📥 Loading AF patients (Test)...
#    Loading mimic_perform_af_005... 1200 windows
#    Loading mimic_perform_af_008... 1200 windows
#    Loading mimic_perform_af_011... 1200 windows
#    Loading mimic_perform_af_013... 1200 windows
#    Loading mimic_perform_af_004... 1200 windows
#    Loading mimic_perform_af_007... 1200 windows
#
# 📥 Loading Non-AF patients (Test)...
#    Loading mimic_perform_non_af_015... 1200 windows
#    Loading mimic_perform_non_af_006... 1200 windows
#    Loading mimic_perform_non_af_012... 1200 windows
#    Loading mimic_perform_non_af_008... 1200 windows
#    Loading mimic_perform_non_af_002... 1200 windows
#    Loading mimic_perform_non_af_005... 1200 windows
#
# ============================================================
# ✅ DATA LOADED
# ============================================================
#
# 📊 Training Data:
#    Samples: 24000
#    AF: 12000 (50.0%)
#    Non-AF: 12000 (50.0%)
#
# 📊 Test Data:
#    Samples: 14400
#    AF: 7200 (50.0%)
#    Non-AF: 7200 (50.0%)

# %% [markdown]
# ## Preprocessing

# %%
# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("✅ Features normalized")
print(f"   Train shape: {X_train_scaled.shape}")
print(f"   Test shape: {X_test_scaled.shape}")
# Out:
# ✅ Features normalized
#    Train shape: (24000, 5)
#    Test shape: (14400, 5)

# %%
def create_sequences(data, labels, sequence_length=10):
    """
    Create sequences for LSTM.
    """
    X_seq = []
    y_seq = []
    
    for i in range(len(data) - sequence_length + 1):
        X_seq.append(data[i:i+sequence_length])
        y_seq.append(labels[i+sequence_length-1])
    
    return np.array(X_seq), np.array(y_seq)

# Create sequences
print(f"Creating sequences with {SEQUENCE_LENGTH} timesteps...")

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, SEQUENCE_LENGTH)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, SEQUENCE_LENGTH)

print(f"\n✅ Sequences created:")
print(f"   X_train: {X_train_seq.shape}")
print(f"   X_test: {X_test_seq.shape}")
# Out:
# Creating sequences with 10 timesteps...
#
# ✅ Sequences created:
#    X_train: (23991, 10, 5)
#    X_test: (14391, 10, 5)

# %% [markdown]
# # Transfomer Model

# %% [markdown]
# ### Grid Search

# %% [markdown]
# #### Model

# %%
def build_transformer_model(n_timesteps=SEQUENCE_LENGTH, n_features=5, num_heads=2, ff_dim=32, dropout_rate=0.2):
    """
    Build Transformer model for Grid Search
    """
    inputs = Input(shape=(n_timesteps, n_features))
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=n_features)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Flatten()(x)
    x = Dense(ff_dim, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap model for scikit-learn
keras_clf = KerasClassifier(
    build_fn=build_transformer_model,
    n_timesteps=SEQUENCE_LENGTH,
    n_features=5,
    verbose=0
)

# Hyperparameter grid
param_grid = {
    'epochs': [20, 30],
    'batch_size': [32, 64],
    'model__num_heads': [2, 4],   
    'model__ff_dim': [32, 64],
    'model__dropout_rate': [0.1, 0.2]
}

# Define GridSearchCV
grid = GridSearchCV(
    estimator=keras_clf, 
    param_grid=param_grid, 
    cv=3, 
    scoring='accuracy', 
    n_jobs=-1
)

print("✅ Transformer model and GridSearchCV defined")
print(f"   Total combinations: {len(param_grid['epochs']) * len(param_grid['batch_size']) * len(param_grid['model__num_heads']) * len(param_grid['model__ff_dim']) * len(param_grid['model__dropout_rate'])}")
# Out:
# ✅ Transformer model and GridSearchCV defined
#    Total combinations: 32

# %% [markdown]
# #### Running

# %%
# Compute class weights
class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
class_weight_dict = dict(enumerate(class_weights_array))

# Fit GridSearchCV
grid_result = grid.fit(X_train_seq, y_train_seq)

# %% [markdown]
# #### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'TRANSFORMER')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'xgboost_transformer_grid_{timestamp}.joblib')
best_transformer_model = grid_result.best_estimator_.model_
joblib.dump(best_transformer_model, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\TRANSFORMER\xgboost_transformer_grid_10122025_050418.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Grid Search

# %% [markdown]
# Score: 0.4919 (+/- 0.2191)
#
# Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__ff_dim': 64, 'model__num_heads': 4}

# %%
print("\n" + "="*60)
print("GRID SEARCH RESULTS")
print("="*60)
print(f"\n✅ Best Score: {grid_result.best_score_:.4f}")
print(f"\n📊 Best Hyperparameters:")
for param, value in grid_result.best_params_.items():
    print(f"   {param}: {value}")

print("\n📊 Top 5 Configurations:")
results_df = pd.DataFrame(grid_result.cv_results_)
results_df = results_df.sort_values('rank_test_score')
for idx, row in results_df.head(5).iterrows():
    print(f"\n   Rank {int(row['rank_test_score'])}:")
    print(f"      Score: {row['mean_test_score']:.4f} (+/- {row['std_test_score']:.4f})")
    print(f"      Params: {row['params']}")

# Visualize Grid Search Results
print("="*60)
print("GRID SEARCH RESULTS VISUALIZATION")
print("="*60)

# Create results dataframe
results_df = pd.DataFrame(grid_result.cv_results_)

# Plot 1: Mean Test Score Distribution
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Hyperparameter vs Score plots
params_to_plot = ['param_model__num_heads', 'param_model__ff_dim', 'param_model__dropout_rate', 
                  'param_batch_size', 'param_epochs']
titles = ['Number of Heads', 'Feed Forward Dim', 'Dropout Rate', 
          'Batch Size', 'Epochs']

for idx, (param, title) in enumerate(zip(params_to_plot, titles)):
    ax = axes[idx // 3, idx % 3]
    
    # Group by parameter and get mean score
    grouped = results_df.groupby(param)['mean_test_score'].mean()
    ax.bar(range(len(grouped)), grouped.values, color='steelblue', alpha=0.7)
    ax.set_xticks(range(len(grouped)))
    ax.set_xticklabels([str(x) for x in grouped.index])
    ax.set_xlabel(title)
    ax.set_ylabel('Mean CV Accuracy')
    ax.set_title(f'Effect of {title}')
    ax.grid(True, alpha=0.3)

# Plot 6: Top 10 Configurations
ax = axes[1, 2]
top_10 = results_df.nsmallest(10, 'rank_test_score')
ax.barh(range(10), top_10['mean_test_score'].values, color='darkorange', alpha=0.7)
ax.set_yticks(range(10))
ax.set_yticklabels([f"Rank {int(r)}" for r in top_10['rank_test_score']])
ax.set_xlabel('Mean CV Accuracy')
ax.set_title('Top 10 Configurations')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('models/TRANSFORMER/grid_search_results.png', dpi=150, bbox_inches='tight')
plt.show()

# Print best parameters summary
print(f"\n✅ Best Configuration:")
print(f"   Accuracy: {grid_result.best_score_:.4f}")
for param, value in grid_result.best_params_.items():
    print(f"   {param}: {value}")
# Out:
# ============================================================
# GRID SEARCH RESULTS
# ============================================================
#
# ✅ Best Score: 0.4919
#
# 📊 Best Hyperparameters:
#    batch_size: 64
#    epochs: 20
#    model__dropout_rate: 0.2
#    model__ff_dim: 64
#    model__num_heads: 4
#
# 📊 Top 5 Configurations:
#
#    Rank 1:
#       Score: 0.4919 (+/- 0.2191)
#       Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__ff_dim': 64, 'model__num_heads': 4}
#
#    Rank 2:
#       Score: 0.4863 (+/- 0.1956)
#       Params: {'batch_size': 32, 'epochs': 30, 'model__dropout_rate': 0.1, 'model__ff_dim': 64, 'model__num_heads': 4}
#
#    Rank 3:
#       Score: 0.4754 (+/- 0.2163)
#       Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__ff_dim': 32, 'model__num_heads': 2}
#
#    Rank 4:
#       Score: 0.4645 (+/- 0.2143)
#       Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.1, 'model__ff_dim': 64, 'model__num_heads': 2}
#
#    Rank 5:
#       Score: 0.4552 (+/- 0.2180)
#       Params: {'batch_size': 64, 'epochs': 30, 'model__dropout_rate': 0.2, 'model__ff_dim': 32, 'model__num_heads': 4}
# ============================================================
# GRID SEARCH RESULTS VISUALIZATION
# ============================================================
# ✅ Best Configuration:
#    Accuracy: 0.4919
#    batch_size: 64
#    epochs: 20
#    model__dropout_rate: 0.2
#    model__ff_dim: 64
#    model__num_heads: 4

# %% [markdown]
# ### Extract Feature

# %%
# Extract features from best Grid Search Transformer model for XGBoost
best_transformer_model = grid_result.best_estimator_.model_

# Build feature extractor from the second-to-last layer
gs_feature_extractor = Model(
    inputs=best_transformer_model.inputs,
    outputs=best_transformer_model.layers[-2].output
)

# Extract features
print("Extracting features from Grid Search Transformer model...")
X_train_weights_gs = gs_feature_extractor.predict(X_train_seq, verbose=0)
X_test_weights_gs = gs_feature_extractor.predict(X_test_seq, verbose=0)

print("✅ Features extracted from Grid Search Transformer model")
print(f"   Train: {X_train_weights_gs.shape}")
print(f"   Test: {X_test_weights_gs.shape}")
# Out:
# Extracting features from Grid Search Transformer model...
# ✅ Features extracted from Grid Search Transformer model
#    Train: (23991, 64)
#    Test: (14391, 64)

# %% [markdown]
# ### Optuna

# %% [markdown]
# #### Model

# %%
def create_transformer_model_optuna(trial):
    """
    Create Transformer model with Optuna hyperparameters
    """
    # Hyperparameters to tune
    num_heads = trial.suggest_categorical('num_heads', [2, 4, 8])
    ff_dim = trial.suggest_categorical('ff_dim', [32, 64, 128])
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    
    # Build model
    inputs = Input(shape=(SEQUENCE_LENGTH, 5))
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=5)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Flatten()(x)
    x = Dense(ff_dim, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    
    return model

print("✅ Transformer model for Optuna defined")
# Out:
# ✅ Transformer model for Optuna defined

# %% [markdown]
# #### Running

# %%
def objective(trial):
    """
    Optuna objective function for Transformer hyperparameter tuning
    """
    # Hyperparameters to tune
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    epochs = trial.suggest_int('epochs', 20, 50)
    
    # Create model
    model = create_transformer_model_optuna(trial)
    
    # Class weights
    class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
    class_weight_dict = dict(enumerate(class_weights_array))
    
    # Train model
    history = model.fit(
        X_train_seq, y_train_seq,
        batch_size=batch_size,
        epochs=epochs,
        class_weight=class_weight_dict,
        validation_split=0.2,
        verbose=0,
        callbacks=[TFKerasPruningCallback(trial, 'val_accuracy')]
    )
    
    return history.history['val_accuracy'][-1]

# Run Optuna optimization
print("="*60)
print("OPTUNA HYPERPARAMETER TUNING - TRANSFORMER")
print("="*60)
print("\nStarting Optuna optimization...")

study = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=30, show_progress_bar=True)

print("\n" + "="*60)
print("OPTUNA RESULTS")
print("="*60)
print(f"\n✅ Best Accuracy: {study.best_value:.4f}")
print(f"\n📊 Best Hyperparameters:")
for param, value in study.best_params.items():
    print(f"   {param}: {value}")
# Out:
# [I 2025-12-10 03:04:47,197] A new study created in memory with name: no-name-6c87b56d-2ac6-4f46-bf9e-b59d8303bde5
# ============================================================
# OPTUNA HYPERPARAMETER TUNING - TRANSFORMER
# ============================================================
#
# Starting Optuna optimization...
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-12-10 03:06:17,354] Trial 0 finished with value: 0.477807879447937 and parameters: {'batch_size': 128, 'epochs': 26, 'num_heads': 8, 'ff_dim': 32, 'dropout_rate': 0.43751724476161546, 'learning_rate': 0.0002555720047129161}. Best is trial 0 with value: 0.477807879447937.
# [I 2025-12-10 03:08:38,061] Trial 1 finished with value: 0.49406126141548157 and parameters: {'batch_size': 128, 'epochs': 33, 'num_heads': 8, 'ff_dim': 32, 'dropout_rate': 0.36924935029318484, 'learning_rate': 0.00018581328175333058}. Best is trial 1 with value: 0.49406126141548157.
# [I 2025-12-10 03:11:34,458] Trial 2 finished with value: 0.4717649519443512 and parameters: {'batch_size': 32, 'epochs': 29, 'num_heads': 4, 'ff_dim': 64, 'dropout_rate': 0.27865273122219436, 'learning_rate': 0.002756821957965035}. Best is trial 1 with value: 0.49406126141548157.
# [I 2025-12-10 03:14:00,341] Trial 3 finished with value: 0.45363616943359375 and parameters: {'batch_size': 32, 'epochs': 28, 'num_heads': 2, 'ff_dim': 64, 'dropout_rate': 0.1766554014793815, 'learning_rate': 0.0010113721332072369}. Best is trial 1 with value: 0.49406126141548157.
# [I 2025-12-10 03:15:28,130] Trial 4 finished with value: 0.4821837842464447 and parameters: {'batch_size': 128, 'epochs': 27, 'num_heads': 4, 'ff_dim': 128, 'dropout_rate': 0.13088856925995007, 'learning_rate': 0.00020750716559340425}. Best is trial 1 with value: 0.49406126141548157.
# [I 2025-12-10 03:15:40,553] Trial 5 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:21:59,462] Trial 6 finished with value: 0.4846843183040619 and parameters: {'batch_size': 32, 'epochs': 45, 'num_heads': 8, 'ff_dim': 32, 'dropout_rate': 0.47376963018126916, 'learning_rate': 0.00012568782302116696}. Best is trial 1 with value: 0.49406126141548157.
# [I 2025-12-10 03:22:05,763] Trial 7 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:22:14,716] Trial 8 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:23:54,277] Trial 9 finished with value: 0.49093562364578247 and parameters: {'batch_size': 128, 'epochs': 21, 'num_heads': 8, 'ff_dim': 64, 'dropout_rate': 0.48258626637394353, 'learning_rate': 0.0017834900031833288}. Best is trial 1 with value: 0.49406126141548157.
# [I 2025-12-10 03:28:59,395] Trial 10 finished with value: 0.4961450397968292 and parameters: {'batch_size': 64, 'epochs': 37, 'num_heads': 8, 'ff_dim': 128, 'dropout_rate': 0.35018388304679765, 'learning_rate': 0.00045732137933487954}. Best is trial 10 with value: 0.4961450397968292.
# [I 2025-12-10 03:34:09,198] Trial 11 finished with value: 0.47155657410621643 and parameters: {'batch_size': 64, 'epochs': 37, 'num_heads': 8, 'ff_dim': 128, 'dropout_rate': 0.35751357256925476, 'learning_rate': 0.00043280612392787175}. Best is trial 10 with value: 0.4961450397968292.
# [I 2025-12-10 03:34:23,386] Trial 12 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:39:24,412] Trial 13 finished with value: 0.4967701733112335 and parameters: {'batch_size': 64, 'epochs': 41, 'num_heads': 8, 'ff_dim': 128, 'dropout_rate': 0.4037450941514691, 'learning_rate': 0.00010064162612495603}. Best is trial 13 with value: 0.4967701733112335.
# [I 2025-12-10 03:39:36,413] Trial 14 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:39:46,992] Trial 15 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:39:59,171] Trial 16 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:43:54,480] Trial 17 finished with value: 0.47009792923927307 and parameters: {'batch_size': 64, 'epochs': 40, 'num_heads': 8, 'ff_dim': 128, 'dropout_rate': 0.3153986907763438, 'learning_rate': 0.001146906656682363}. Best is trial 13 with value: 0.4967701733112335.
# [I 2025-12-10 03:46:30,686] Trial 18 finished with value: 0.4563450813293457 and parameters: {'batch_size': 64, 'epochs': 46, 'num_heads': 2, 'ff_dim': 128, 'dropout_rate': 0.40997767535494545, 'learning_rate': 0.000638766242344492}. Best is trial 13 with value: 0.4967701733112335.
# [I 2025-12-10 03:46:34,625] Trial 19 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:46:40,466] Trial 20 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:46:46,097] Trial 21 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:46:50,812] Trial 22 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:49:22,398] Trial 23 finished with value: 0.4951031506061554 and parameters: {'batch_size': 64, 'epochs': 40, 'num_heads': 8, 'ff_dim': 64, 'dropout_rate': 0.3572569733577228, 'learning_rate': 0.00011935278813299752}. Best is trial 13 with value: 0.4967701733112335.
# [I 2025-12-10 03:49:26,875] Trial 24 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:49:31,584] Trial 25 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:51:56,236] Trial 26 finished with value: 0.47634923458099365 and parameters: {'batch_size': 64, 'epochs': 38, 'num_heads': 8, 'ff_dim': 64, 'dropout_rate': 0.23082898529656362, 'learning_rate': 0.0002985031463142483}. Best is trial 13 with value: 0.4967701733112335.
# [I 2025-12-10 03:52:02,897] Trial 27 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:52:09,047] Trial 28 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 03:53:34,002] Trial 29 finished with value: 0.30381330847740173 and parameters: {'batch_size': 64, 'epochs': 30, 'num_heads': 2, 'ff_dim': 64, 'dropout_rate': 0.4300224946788695, 'learning_rate': 0.00025519042803664305}. Best is trial 13 with value: 0.4967701733112335.
#
# ============================================================
# OPTUNA RESULTS
# ============================================================
#
# ✅ Best Accuracy: 0.4968
#
# 📊 Best Hyperparameters:
#    batch_size: 64
#    epochs: 41
#    num_heads: 8
#    ff_dim: 128
#    dropout_rate: 0.4037450941514691
#    learning_rate: 0.00010064162612495603

# %% [markdown]
# #### Save Model

# %%
# Save best Optuna Transformer model
os.makedirs('models/TRANSFORMER', exist_ok=True)
timestamp = dt.now().strftime('%d%m%Y_%H%M%S')

# Rebuild model with best params and retrain on full data
best_trial = study.best_trial
best_model = create_transformer_model_optuna(best_trial)

# Class weights
class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
class_weight_dict = dict(enumerate(class_weights_array))

# Retrain on full data
best_model.fit(
    X_train_seq, y_train_seq,
    batch_size=best_trial.params['batch_size'],
    epochs=best_trial.params['epochs'],
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.7451 - loss: 0.5043
# Epoch 2/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8908 - loss: 0.2815
# Epoch 3/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9280 - loss: 0.2008
# Epoch 4/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9483 - loss: 0.1586
# Epoch 5/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9590 - loss: 0.1349
# Epoch 6/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9656 - loss: 0.1202
# Epoch 7/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9702 - loss: 0.1078
# Epoch 8/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9723 - loss: 0.1025
# Epoch 9/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9732 - loss: 0.0993
# Epoch 10/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9755 - loss: 0.0948
# Epoch 11/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9762 - loss: 0.0903
# Epoch 12/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9770 - loss: 0.0888
# Epoch 13/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9786 - loss: 0.0855
# Epoch 14/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9787 - loss: 0.0837
# Epoch 15/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9792 - loss: 0.0800
# Epoch 16/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9808 - loss: 0.0757
# Epoch 17/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9818 - loss: 0.0725
# Epoch 18/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9821 - loss: 0.0720
# Epoch 19/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9843 - loss: 0.0674
# Epoch 20/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9823 - loss: 0.0677
# Epoch 21/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9835 - loss: 0.0660
# Epoch 22/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9847 - loss: 0.0613
# Epoch 23/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9850 - loss: 0.0600
# Epoch 24/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9848 - loss: 0.0597
# Epoch 25/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9853 - loss: 0.0578
# Epoch 26/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9855 - loss: 0.0563
# Epoch 27/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9857 - loss: 0.0550
# Epoch 28/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9867 - loss: 0.0525
# Epoch 29/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9872 - loss: 0.0495
# Epoch 30/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9867 - loss: 0.0495
# Epoch 31/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9867 - loss: 0.0494
# Epoch 32/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9871 - loss: 0.0470
# Epoch 33/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9879 - loss: 0.0450
# Epoch 34/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9875 - loss: 0.0454
# Epoch 35/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9881 - loss: 0.0445
# Epoch 36/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9880 - loss: 0.0439
# Epoch 37/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9882 - loss: 0.0433
# Epoch 38/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9875 - loss: 0.0431
# Epoch 39/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9887 - loss: 0.0413
# Epoch 40/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9890 - loss: 0.0402
# Epoch 41/41
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9893 - loss: 0.0389

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'TRANSFORMER')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'xgboost_transformer_optuna_{timestamp}.joblib')

joblib.dump(best_model, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\TRANSFORMER\xgboost_transformer_optuna_10122025_050346.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Optuna

# %% [markdown]
# ✅ Best Optuna Configuration:
#   - Accuracy: 0.4968
#   - batch_size: 64
#   - epochs: 41
#   - num_heads: 8
#   - ff_dim: 128
#   - dropout_rate: 0.4037450941514691
#   - learning_rate: 0.00010064162612495603

# %%
# Visualisasi hasil Optuna Transformer

print("="*60)
print("OPTUNA RESULTS VISUALIZATION")
print("="*60)

# Plot optimization history
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.title("Optuna Optimization History (Validation Accuracy)")
plt.show()

# Plot parameter importance
optuna.visualization.matplotlib.plot_param_importances(study)
plt.title("Optuna Hyperparameter Importances")
plt.show()

# Print best trial summary
print(f"\n✅ Best Optuna Configuration:")
print(f"   Accuracy: {study.best_value:.4f}")
for param, value in study.best_params.items():
    print(f"   {param}: {value}")
# Out:
# ============================================================
# OPTUNA RESULTS VISUALIZATION
# ============================================================
# ✅ Best Optuna Configuration:
#    Accuracy: 0.4968
#    batch_size: 64
#    epochs: 41
#    num_heads: 8
#    ff_dim: 128
#    dropout_rate: 0.4037450941514691
#    learning_rate: 0.00010064162612495603

# %% [markdown]
# #### Extraxt Feature

# %%
# Extract features from best Optuna Transformer model for XGBoost
# Build feature extractor from the second-to-last layer
optuna_feature_extractor = Model(
    inputs=best_model.inputs,
    outputs=best_model.layers[-2].output
)

print("Extracting features from Optuna Transformer model...")
X_train_weights_optuna = optuna_feature_extractor.predict(X_train_seq, verbose=0)
X_test_weights_optuna = optuna_feature_extractor.predict(X_test_seq, verbose=0)

print("✅ Features extracted from Optuna Transformer model")
print(f"   Train: {X_train_weights_optuna.shape}")
print(f"   Test: {X_test_weights_optuna.shape}")
# Out:
# Extracting features from Optuna Transformer model...
# ✅ Features extracted from Optuna Transformer model
#    Train: (23991, 128)
#    Test: (14391, 128)

# %% [markdown]
# ### Default

# %% [markdown]
# #### Model

# %%
# Build default Transformer model
def build_transformer_model_default(n_timesteps=SEQUENCE_LENGTH, n_features=5, num_heads=2, ff_dim=32, dropout_rate=0.2):
    """
    Build default Transformer model.
    """
    inputs = Input(shape=(n_timesteps, n_features))
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=n_features)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Flatten()(x)
    x = Dense(ff_dim, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

print("✅ AttentionLayer and default Transformer model defined")
# Out:
# ✅ AttentionLayer and default Transformer model defined

# %% [markdown]
# #### Training

# %%
# Build default Transformer model
model = build_transformer_model_default(
    n_timesteps=SEQUENCE_LENGTH,
    n_features=5,
    num_heads=2,
    ff_dim=32,
    dropout_rate=0.2
)

print("Model Architecture:")
model.summary()

# Train model (tanpa validation - sesuai jurnal)
print("\nTraining Default Transformer Model...")

# Class weights untuk handle imbalance
class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
class_weight_dict = dict(enumerate(class_weights_array))
print(f"Class weights: {class_weight_dict}")

history = model.fit(
    X_train_seq, y_train_seq,
    epochs=50,
    batch_size=64,
    class_weight=class_weight_dict,
    verbose=1
)

print(f"\n✅ Training completed.")
print(f"   Final accuracy: {history.history['accuracy'][-1]:.4f}")
# Out:
# Model Architecture:
# Model: "functional_41"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_39      │ (None, 10, 5)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 10, 5)     │         10 │ input_layer_39[0… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 10, 5)     │        235 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_118         │ (None, 10, 5)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_39          │ (None, 50)        │          0 │ dropout_118[0][0] │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_78 (Dense)    │ (None, 32)        │      1,632 │ flatten_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_119         │ (None, 32)        │          0 │ dense_78[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_79 (Dense)    │ (None, 1)         │         33 │ dropout_119[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,910 (7.46 KB)
#  Trainable params: 1,910 (7.46 KB)
#  Non-trainable params: 0 (0.00 B)
# Training Default Transformer Model...
# Class weights: {0: np.float64(0.999625), 1: np.float64(1.0003752814610958)}
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8948 - loss: 0.2596
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9712 - loss: 0.1043
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9777 - loss: 0.0834
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9814 - loss: 0.0719
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9841 - loss: 0.0619
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9863 - loss: 0.0548
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9886 - loss: 0.0485
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9892 - loss: 0.0455
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9911 - loss: 0.0391
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9922 - loss: 0.0361
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9924 - loss: 0.0339
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9927 - loss: 0.0315
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9935 - loss: 0.0295
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9924 - loss: 0.0305
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9933 - loss: 0.0294
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9937 - loss: 0.0265
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9939 - loss: 0.0260
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9940 - loss: 0.0257
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9938 - loss: 0.0254
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9943 - loss: 0.0256
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9940 - loss: 0.0244
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9940 - loss: 0.0241
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9939 - loss: 0.0234
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9944 - loss: 0.0224
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9945 - loss: 0.0221
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9943 - loss: 0.0218
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9943 - loss: 0.0214
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9942 - loss: 0.0208
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9946 - loss: 0.0193
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9946 - loss: 0.0191
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9946 - loss: 0.0205
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9942 - loss: 0.0189
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9945 - loss: 0.0192
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9948 - loss: 0.0180
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9950 - loss: 0.0178
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9940 - loss: 0.0208
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9950 - loss: 0.0182
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9945 - loss: 0.0184
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9947 - loss: 0.0176
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9945 - loss: 0.0171
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9942 - loss: 0.0181
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9948 - loss: 0.0172
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9950 - loss: 0.0168
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9948 - loss: 0.0165
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9953 - loss: 0.0161
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9946 - loss: 0.0177
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9949 - loss: 0.0161
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9954 - loss: 0.0148
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9950 - loss: 0.0153
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9948 - loss: 0.0172
#
# ✅ Training completed.
#    Final accuracy: 0.9948

# %% [markdown]
# #### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'TRANSFORMER')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'xgboost_transformer_default_{timestamp}.joblib')

joblib.dump(model, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\TRANSFORMER\xgboost_transformer_default_10122025_050311.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Default

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Extract Features

# %%
transformer_default_feature_extractor = Model( # Ubah nama
    inputs=model.inputs, 
    outputs=model.layers[-2].output 
)

# Extract features
print("Extracting features from Transformer model...")
X_train_weights_default = transformer_default_feature_extractor.predict(X_train_seq, verbose=0) # Ubah nama
X_test_weights_default = transformer_default_feature_extractor.predict(X_test_seq, verbose=0)   # Ubah nama

print("✅ Features extracted from Transformer model")
print(f"   Train: {X_train_weights_default.shape}")
print(f"   Test: {X_test_weights_default.shape}")
# Out:
# Extracting features from Transformer model...
# ✅ Features extracted from Transformer model
#    Train: (23991, 32)
#    Test: (14391, 32)

# %% [markdown]
# # XGBoost Classifier

# %% [markdown]
# ### Grid search

# %% [markdown]
# #### Model

# %%
# Parameter grid sesuai jurnal dan variasi
param_grid_xgb = {
    'eta': [0.1, 0.2, 0.3],
    'n_estimators': [100, 170, 200],
    'max_depth': [8, 10, 12]
}

xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

grid_xgb = GridSearchCV(
    estimator=xgb_clf,
    param_grid=param_grid_xgb,
    scoring='accuracy',
    cv=3,
    n_jobs=-1,
    verbose=2
)

# %% [markdown]
# #### Running

# %%
print("Training XGBoost GridSearchCV with features from Grid Search Transformer...")
grid_xgb.fit(X_train_weights_gs, y_train_seq)
print("✅ GridSearchCV completed")
print(f"Best params: {grid_xgb.best_params_}")
print(f"Best score: {grid_xgb.best_score_:.4f}")
# Out:
# Training XGBoost GridSearchCV with features from Grid Search Transformer...
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# ✅ GridSearchCV completed
# Best params: {'eta': 0.3, 'max_depth': 10, 'n_estimators': 100}
# Best score: 0.9780

# %% [markdown]
# #### Save Model

# %%
BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"

MODEL_DIR = os.path.join(BASE_DIR, 'models', 'XGBOOST')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'xgboost_transformer_grid_{timestamp}.joblib')

# Pastikan Anda menggunakan joblib.dump()
joblib.dump(grid_xgb.best_estimator_, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\XGBOOST\xgboost_transformer_grid_10122025_044631.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Grid Search

# %%
print("="*60)
print("XGBOOST GRID SEARCH RESULTS")
print("="*60)

# Best Score & Hyperparameters
print(f"\n✅ Best Accuracy: {grid_xgb.best_score_:.4f}")
print(f"\n📊 Best Hyperparameters:")
for param, value in grid_xgb.best_params_.items():
    print(f"   {param}: {value}")

# Top 5 Configurations
results_xgb_df = pd.DataFrame(grid_xgb.cv_results_).sort_values('rank_test_score')
print("\n📊 Top 5 Configurations:")
for idx, row in results_xgb_df.head(5).iterrows():
    print(f"\n   Rank {int(row['rank_test_score'])}:")
    print(f"      Accuracy: {row['mean_test_score']:.4f} (+/- {row['std_test_score']:.4f})")
    print(f"      Params  : {row['params']}")

print("\n" + "="*60)
print("CONFUSION MATRIX & METRICS")
print("="*60)

# Metrics
y_pred_xgb = grid_xgb.predict(X_test_weights_gs)
y_prob_xgb = grid_xgb.predict_proba(X_test_weights_gs)[:, 1]
acc_xgb = accuracy_score(y_test_seq, y_pred_xgb)
prec_xgb = precision_score(y_test_seq, y_pred_xgb, zero_division=0)
recall_xgb = recall_score(y_test_seq, y_pred_xgb, zero_division=0)
f1_xgb = f1_score(y_test_seq, y_pred_xgb, zero_division=0)
rocauc_xgb = roc_auc_score(y_test_seq, y_prob_xgb) if len(np.unique(y_pred_xgb)) > 1 else 0.5

print(f"\n✅ Performance Metrics:")
print(f"   Accuracy : {acc_xgb:.4f} ({acc_xgb*100:.2f}%)")
print(f"   Precision: {prec_xgb:.4f} ({prec_xgb*100:.2f}%)")
print(f"   Recall   : {recall_xgb:.4f} ({recall_xgb*100:.2f}%)")
print(f"   F1 Score : {f1_xgb:.4f} ({f1_xgb*100:.2f}%)")
print(f"   ROC AUC  : {rocauc_xgb:.4f} ({rocauc_xgb*100:.2f}%)")

# Confusion Matrix & ROC Curve side by side
cm_xgb = confusion_matrix(y_test_seq, y_pred_xgb)
fpr, tpr, thresholds = roc_curve(y_test_seq, y_prob_xgb)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
disp_xgb = ConfusionMatrixDisplay(confusion_matrix=cm_xgb, display_labels=['Non-AF', 'AF'])
disp_xgb.plot(cmap='Blues', ax=axes[0], colorbar=False)
axes[0].set_title('Confusion Matrix - XGBoost Grid Search')

# ROC Curve
axes[1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {rocauc_xgb:.2f})')
axes[1].plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
axes[1].set_xlim([0.0, 1.0])
axes[1].set_ylim([0.0, 1.05])
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve - XGBoost Grid Search')
axes[1].legend(loc="lower right")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_test_seq, y_pred_xgb, target_names=['Non-AF', 'AF'], zero_division=0))
# Out:
# ============================================================
# XGBOOST GRID SEARCH RESULTS
# ============================================================
#
# ✅ Best Accuracy: 0.9780
#
# 📊 Best Hyperparameters:
#    eta: 0.3
#    max_depth: 10
#    n_estimators: 100
#
# 📊 Top 5 Configurations:
#
#    Rank 1:
#       Accuracy: 0.9780 (+/- 0.0138)
#       Params  : {'eta': 0.3, 'max_depth': 12, 'n_estimators': 100}
#
#    Rank 1:
#       Accuracy: 0.9780 (+/- 0.0138)
#       Params  : {'eta': 0.3, 'max_depth': 10, 'n_estimators': 100}
#
#    Rank 3:
#       Accuracy: 0.9766 (+/- 0.0159)
#       Params  : {'eta': 0.3, 'max_depth': 12, 'n_estimators': 170}
#
#    Rank 4:
#       Accuracy: 0.9764 (+/- 0.0158)
#       Params  : {'eta': 0.3, 'max_depth': 10, 'n_estimators': 170}
#
#    Rank 5:
#       Accuracy: 0.9756 (+/- 0.0173)
#       Params  : {'eta': 0.3, 'max_depth': 12, 'n_estimators': 200}
#
# ============================================================
# CONFUSION MATRIX & METRICS
# ============================================================
#
# ✅ Performance Metrics:
#    Accuracy : 0.5241 (52.41%)
#    Precision: 0.5179 (51.79%)
#    Recall   : 0.6881 (68.81%)
#    F1 Score : 0.5910 (59.10%)
#    ROC AUC  : 0.4814 (48.14%)
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#       Non-AF       0.54      0.36      0.43      7200
#           AF       0.52      0.69      0.59      7191
#
#     accuracy                           0.52     14391
#    macro avg       0.53      0.52      0.51     14391
# weighted avg       0.53      0.52      0.51     14391

# %% [markdown]
# ### Optuna

# %% [markdown]
# #### Model

# %% [markdown]
# #### Running

# %%
import optuna
from sklearn.model_selection import KFold

# Optuna hyperparameter tuning for XGBoost (features from Optuna Transformer)
def objective_xgb(trial):
    param = {
        'eta': trial.suggest_float('eta', 0.05, 0.3),
        'max_depth': trial.suggest_int('max_depth', 6, 14),
        'n_estimators': trial.suggest_int('n_estimators', 100, 250),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
        'eval_metric': 'logloss',
        'use_label_encoder': False
    }
    xgb = XGBClassifier(**param)
    scores = []
    # 3-fold cross-validation
    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    for train_idx, val_idx in kf.split(X_train_weights_optuna):
        X_tr, X_val = X_train_weights_optuna[train_idx], X_train_weights_optuna[val_idx]
        y_tr, y_val = y_train_seq[train_idx], y_train_seq[val_idx]
        xgb.fit(X_tr, y_tr)
        preds = xgb.predict(X_val)
        scores.append(accuracy_score(y_val, preds))
    return np.mean(scores)


study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgb, n_trials=30, show_progress_bar=True)

print("\n✅ Best XGBoost Optuna params:")
for k, v in study_xgb.best_params.items():
    print(f"   {k}: {v}")
print(f"Best accuracy: {study_xgb.best_value:.4f}")
# Out:
# [I 2025-12-10 04:27:36,533] A new study created in memory with name: no-name-f84bea2e-e13f-442a-ad88-6a69f4150dea
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-12-10 04:27:45,620] Trial 0 finished with value: 0.994956441999083 and parameters: {'eta': 0.26198597498959725, 'max_depth': 9, 'n_estimators': 164, 'subsample': 0.9050167740998392, 'colsample_bytree': 0.9535473422087404}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:27:52,369] Trial 1 finished with value: 0.9946646659163854 and parameters: {'eta': 0.15056872207778005, 'max_depth': 9, 'n_estimators': 109, 'subsample': 0.7604887470461719, 'colsample_bytree': 0.8839205535020123}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:27:57,596] Trial 2 finished with value: 0.9945813013213288 and parameters: {'eta': 0.15894843213845872, 'max_depth': 6, 'n_estimators': 111, 'subsample': 0.8742266881519538, 'colsample_bytree': 0.8671202217713795}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:04,757] Trial 3 finished with value: 0.9947480305114418 and parameters: {'eta': 0.1693450593722205, 'max_depth': 6, 'n_estimators': 166, 'subsample': 0.924005530786695, 'colsample_bytree': 0.7354306499432426}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:10,686] Trial 4 finished with value: 0.9947063482139136 and parameters: {'eta': 0.1734995757012831, 'max_depth': 8, 'n_estimators': 114, 'subsample': 0.8457817335664995, 'colsample_bytree': 0.7303524251862981}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:16,759] Trial 5 finished with value: 0.9949147597015547 and parameters: {'eta': 0.22347209514835265, 'max_depth': 12, 'n_estimators': 102, 'subsample': 0.8947143217966016, 'colsample_bytree': 0.8214318140355027}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:23,299] Trial 6 finished with value: 0.9940394314534617 and parameters: {'eta': 0.06440338311471631, 'max_depth': 9, 'n_estimators': 102, 'subsample': 0.915410145601045, 'colsample_bytree': 0.9060987540789021}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:30,858] Trial 7 finished with value: 0.99408111375099 and parameters: {'eta': 0.05534703424365449, 'max_depth': 7, 'n_estimators': 152, 'subsample': 0.9256560876053003, 'colsample_bytree': 0.7247322604385914}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:38,005] Trial 8 finished with value: 0.9947063482139136 and parameters: {'eta': 0.2250586775672208, 'max_depth': 9, 'n_estimators': 134, 'subsample': 0.9321353456759768, 'colsample_bytree': 0.8477310220524952}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:47,021] Trial 9 finished with value: 0.9945396190238006 and parameters: {'eta': 0.27373707430848526, 'max_depth': 14, 'n_estimators': 184, 'subsample': 0.7751249383483042, 'colsample_bytree': 0.7010318014651755}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:28:57,589] Trial 10 finished with value: 0.9947063482139136 and parameters: {'eta': 0.295634909180051, 'max_depth': 11, 'n_estimators': 233, 'subsample': 0.9903962333138032, 'colsample_bytree': 0.9693483996019705}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:29:07,298] Trial 11 finished with value: 0.9949147597015547 and parameters: {'eta': 0.23543985304451437, 'max_depth': 12, 'n_estimators': 206, 'subsample': 0.8265272517678923, 'colsample_bytree': 0.8081793990916718}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:29:17,449] Trial 12 finished with value: 0.994956441999083 and parameters: {'eta': 0.233294814623195, 'max_depth': 13, 'n_estimators': 196, 'subsample': 0.9939366578929298, 'colsample_bytree': 0.9842229971646868}. Best is trial 0 with value: 0.994956441999083.
# [I 2025-12-10 04:29:27,281] Trial 13 finished with value: 0.9950398065941394 and parameters: {'eta': 0.2522936617569491, 'max_depth': 14, 'n_estimators': 191, 'subsample': 0.9978256361153854, 'colsample_bytree': 0.9849606176582326}. Best is trial 13 with value: 0.9950398065941394.
# [I 2025-12-10 04:29:37,928] Trial 14 finished with value: 0.9951648534867242 and parameters: {'eta': 0.26751533159974195, 'max_depth': 10, 'n_estimators': 236, 'subsample': 0.9657889670262658, 'colsample_bytree': 0.9358417822755751}. Best is trial 14 with value: 0.9951648534867242.
# [I 2025-12-10 04:29:51,119] Trial 15 finished with value: 0.9947063482139136 and parameters: {'eta': 0.10877599726047857, 'max_depth': 11, 'n_estimators': 248, 'subsample': 0.9542696337184958, 'colsample_bytree': 0.920358358583747}. Best is trial 14 with value: 0.9951648534867242.
# [I 2025-12-10 04:30:00,812] Trial 16 finished with value: 0.99478971280897 and parameters: {'eta': 0.29877288829241333, 'max_depth': 14, 'n_estimators': 216, 'subsample': 0.7121855729845128, 'colsample_bytree': 0.9994630542420966}. Best is trial 14 with value: 0.9951648534867242.
# [I 2025-12-10 04:30:12,203] Trial 17 finished with value: 0.9951648534867242 and parameters: {'eta': 0.20302341757055534, 'max_depth': 11, 'n_estimators': 224, 'subsample': 0.9716958020232316, 'colsample_bytree': 0.9392884265826261}. Best is trial 14 with value: 0.9951648534867242.
# [I 2025-12-10 04:30:23,109] Trial 18 finished with value: 0.9952482180817807 and parameters: {'eta': 0.20745227600815197, 'max_depth': 11, 'n_estimators': 227, 'subsample': 0.9619630762714292, 'colsample_bytree': 0.9346421896595}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:30:34,713] Trial 19 finished with value: 0.9947480305114418 and parameters: {'eta': 0.1943880937131875, 'max_depth': 10, 'n_estimators': 249, 'subsample': 0.9570696926093112, 'colsample_bytree': 0.9065550107442865}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:30:46,502] Trial 20 finished with value: 0.99478971280897 and parameters: {'eta': 0.12662779596832854, 'max_depth': 10, 'n_estimators': 232, 'subsample': 0.8195120975625358, 'colsample_bytree': 0.782766583541976}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:30:57,261] Trial 21 finished with value: 0.9947480305114418 and parameters: {'eta': 0.1998040698461985, 'max_depth': 11, 'n_estimators': 221, 'subsample': 0.9630462706572657, 'colsample_bytree': 0.935843066179465}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:31:08,716] Trial 22 finished with value: 0.9950398065941394 and parameters: {'eta': 0.20080465294945923, 'max_depth': 12, 'n_estimators': 231, 'subsample': 0.9626833961420235, 'colsample_bytree': 0.9444316383102976}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:31:18,236] Trial 23 finished with value: 0.9946646659163854 and parameters: {'eta': 0.27587670248377316, 'max_depth': 10, 'n_estimators': 206, 'subsample': 0.8791077492317536, 'colsample_bytree': 0.8892385947288977}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:31:28,985] Trial 24 finished with value: 0.9947480305114418 and parameters: {'eta': 0.1975281300723154, 'max_depth': 11, 'n_estimators': 218, 'subsample': 0.9781061907871371, 'colsample_bytree': 0.9557408469911141}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:31:41,181] Trial 25 finished with value: 0.9949147597015547 and parameters: {'eta': 0.14067039867195325, 'max_depth': 10, 'n_estimators': 240, 'subsample': 0.9441648931454028, 'colsample_bytree': 0.9228232716942251}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:31:51,274] Trial 26 finished with value: 0.9948313951064982 and parameters: {'eta': 0.2487862111520142, 'max_depth': 13, 'n_estimators': 207, 'subsample': 0.9750499719015873, 'colsample_bytree': 0.8553829530778989}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:32:01,600] Trial 27 finished with value: 0.9947063482139136 and parameters: {'eta': 0.2137072418437267, 'max_depth': 8, 'n_estimators': 222, 'subsample': 0.8800604145462647, 'colsample_bytree': 0.8853988528361926}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:32:13,752] Trial 28 finished with value: 0.9948730774040265 and parameters: {'eta': 0.18737431839688076, 'max_depth': 12, 'n_estimators': 241, 'subsample': 0.9376229141414243, 'colsample_bytree': 0.9687407901710019}. Best is trial 18 with value: 0.9952482180817807.
# [I 2025-12-10 04:32:22,254] Trial 29 finished with value: 0.9947897128089701 and parameters: {'eta': 0.26332159853140835, 'max_depth': 8, 'n_estimators': 178, 'subsample': 0.902625265157333, 'colsample_bytree': 0.9318539508218575}. Best is trial 18 with value: 0.9952482180817807.
#
# ✅ Best XGBoost Optuna params:
#    eta: 0.20745227600815197
#    max_depth: 11
#    n_estimators: 227
#    subsample: 0.9619630762714292
#    colsample_bytree: 0.9346421896595
# Best accuracy: 0.9952

# %%
# Train XGBoost with Optuna best parameters using features from Optuna Transformer
xgb_optuna = XGBClassifier(**study_xgb.best_params, use_label_encoder=False, eval_metric='logloss')

print("Training XGBoost with Optuna best parameters (Optuna Transformer features)...")
xgb_optuna.fit(X_train_weights_optuna, y_train_seq)
print("✅ XGBoost (Optuna) trained")
# Out:
# Training XGBoost with Optuna best parameters (Optuna Transformer features)...
# ✅ XGBoost (Optuna) trained

# %% [markdown]
# ### Save Model

# %%
# Save best XGBoost model from GridSearchCV
os.makedirs('models/XGBOOST', exist_ok=True)
timestamp = dt.now().strftime('%d%m%Y_%H%M%S')

xgb_optuna.save_model(f'models/XGBOOST/xgboost_transformer_optuna_{timestamp}.joblib')

print("✅ Best XGBoost model from Optuna saved!")
print(f"   Model: models/XGBOOST/xgboost_transformer_optuna_{timestamp}.joblib")
# Out:
# ✅ Best XGBoost model from Optuna saved!
#    Model: models/XGBOOST/xgboost_transformer_optuna_10122025_043722.joblib

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'XGBOOST')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'xgboost_transformer_optuna_{timestamp}.joblib')


joblib.dump(xgb_optuna, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\XGBOOST\xgboost_transformer_optuna_10122025_044957.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Optuna

# %%
# Evaluate XGBoost Optuna model
y_prob_optuna = xgb_optuna.predict_proba(X_test_weights_optuna)[:, 1]
y_pred_optuna = xgb_optuna.predict(X_test_weights_optuna)

# Metrics
acc_optuna = accuracy_score(y_test_seq, y_pred_optuna)
prec_optuna = precision_score(y_test_seq, y_pred_optuna, zero_division=0)
recall_optuna = recall_score(y_test_seq, y_pred_optuna, zero_division=0)
f1_optuna = f1_score(y_test_seq, y_pred_optuna, zero_division=0)
roauc_optuna = roc_auc_score(y_test_seq, y_prob_optuna) if len(np.unique(y_pred_optuna)) > 1 else 0.5

print("="*60)
print("HYBRID MODEL EVALUATION (Optuna Transformer + XGBoost)")
print("Dataset: MIMIC Perform AF")
print("="*60)
print(f"\n📊 Performance Metrics:")
print(f"   Accuracy : {acc_optuna:.4f} ({acc_optuna*100:.2f}%)")
print(f"   Precision: {prec_optuna:.4f} ({prec_optuna*100:.2f}%)")
print(f"   Recall   : {recall_optuna:.4f} ({recall_optuna*100:.2f}%)")
print(f"   F1 Score : {f1_optuna:.4f} ({f1_optuna*100:.2f}%)")
print(f"   ROC AUC  : {roauc_optuna:.4f} ({roauc_optuna*100:.2f}%)")

# Confusion Matrix & ROC Curve
cm_optuna = confusion_matrix(y_test_seq, y_pred_optuna)
fpr, tpr, thresholds = roc_curve(y_test_seq, y_prob_optuna)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
disp_optuna = ConfusionMatrixDisplay(confusion_matrix=cm_optuna, display_labels=['Non-AF', 'AF'])
disp_optuna.plot(cmap='Blues', ax=axes[0], colorbar=False)
axes[0].set_title('Confusion Matrix - XGBoost Optuna')

# ROC Curve
axes[1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roauc_optuna:.2f})')
axes[1].plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
axes[1].set_xlim([0.0, 1.0])
axes[1].set_ylim([0.0, 1.05])
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve')
axes[1].legend(loc="lower right")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("Classification Report:")
print("="*60)
print(classification_report(y_test_seq, y_pred_optuna, target_names=['Non-AF', 'AF'], zero_division=0))
# Out:
# ============================================================
# HYBRID MODEL EVALUATION (Optuna Transformer + XGBoost)
# Dataset: MIMIC Perform AF
# ============================================================
#
# 📊 Performance Metrics:
#    Accuracy : 0.5984 (59.84%)
#    Precision: 0.5829 (58.29%)
#    Recall   : 0.6902 (69.02%)
#    F1 Score : 0.6320 (63.20%)
#    ROC AUC  : 0.6263 (62.63%)
# ============================================================
# Classification Report:
# ============================================================
#               precision    recall  f1-score   support
#
#       Non-AF       0.62      0.51      0.56      7200
#           AF       0.58      0.69      0.63      7191
#
#     accuracy                           0.60     14391
#    macro avg       0.60      0.60      0.60     14391
# weighted avg       0.60      0.60      0.60     14391

# %% [markdown]
# ### Default

# %% [markdown]
# #### Model

# %%
xgb_default = XGBClassifier()

# %% [markdown]
# #### Running

# %%
print("Training XGBoost Default (fitur ekstraksi default)...")
xgb_default.fit(X_train_weights_default, y_train_seq)
print("✅ XGBoost Default trained")
# Out:
# Training XGBoost Default (fitur ekstraksi default)...
# ✅ XGBoost Default trained

# %% [markdown]
# #### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'XGBOOST')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'xgboost_transformer_default_{timestamp}.joblib')


joblib.dump(xgb_default, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\XGBOOST\xgboost_transformer_default_10122025_045051.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Default

# %%
# Evaluate XGBoost Default model (template same as Optuna)

y_prob_default = xgb_default.predict_proba(X_test_weights_default)[:, 1]
y_pred_default = xgb_default.predict(X_test_weights_default)

# Metrics
acc_default = accuracy_score(y_test_seq, y_pred_default)
prec_default = precision_score(y_test_seq, y_pred_default, zero_division=0)
recall_default = recall_score(y_test_seq, y_pred_default, zero_division=0)
f1_default = f1_score(y_test_seq, y_pred_default, zero_division=0)
rocauc_default = roc_auc_score(y_test_seq, y_prob_default) if len(np.unique(y_pred_default)) > 1 else 0.5

print("="*60)
print("HYBRID MODEL EVALUATION (Default Transformer + XGBoost)")
print("Dataset: MIMIC Perform AF")
print("="*60)
print(f"\n📊 Performance Metrics:")
print(f"   Accuracy : {acc_default:.4f} ({acc_default*100:.2f}%)")
print(f"   Precision: {prec_default:.4f} ({prec_default*100:.2f}%)")
print(f"   Recall   : {recall_default:.4f} ({recall_default*100:.2f}%)")
print(f"   F1 Score : {f1_default:.4f} ({f1_default*100:.2f}%)")
print(f"   ROC AUC  : {rocauc_default:.4f} ({rocauc_default*100:.2f}%)")

# Confusion Matrix & ROC Curve side by side
cm_default = confusion_matrix(y_test_seq, y_pred_default)
fpr, tpr, thresholds = roc_curve(y_test_seq, y_prob_default)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
disp_default = ConfusionMatrixDisplay(confusion_matrix=cm_default, display_labels=['Non-AF', 'AF'])
disp_default.plot(cmap='Blues', ax=axes[0], colorbar=False)
axes[0].set_title('Confusion Matrix - XGBoost Default')

# ROC Curve
axes[1].plot(fpr, tpr, label=f'ROC curve (AUC = {rocauc_default:.2f})', color='darkorange')
axes[1].plot([0, 1], [0, 1], 'k--', lw=1)
axes[1].set_xlim([0.0, 1.0])
axes[1].set_ylim([0.0, 1.05])
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve - XGBoost Default')
axes[1].legend(loc="lower right")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("Classification Report:")
print("="*60)
print(classification_report(y_test_seq, y_pred_default, target_names=['Non-AF', 'AF'], zero_division=0))

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Perbandingan Metrics

# %%
metrics_df = pd.DataFrame({
    'Model': [
        'XGBoost GridSearch (GS Transformer)', 
        'XGBoost Optuna (Optuna Transformer)', 
        'XGBoost Default (Default Transformer)'
    ],
    'Accuracy': [
        acc_xgb, 
        acc_optuna, 
        acc_default
    ],
    'Precision': [
        prec_xgb, 
        prec_optuna, 
        prec_default
    ],
    'Recall': [
        recall_xgb, 
        recall_optuna, 
        recall_default
    ],
    'F1 Score': [
        f1_xgb, 
        f1_optuna, 
        f1_default
    ],
    'ROC AUC': [
        rocauc_xgb, 
        roauc_optuna, 
        rocauc_default
    ]
})

# Visualisasi perbandingan metrik
metrics_plot = metrics_df.set_index('Model')
metrics_plot.plot(kind='bar', figsize=(12, 6))
plt.title('Perbandingan Semua Metric XGBoost (Transformer Features)')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.grid(axis='y', alpha=0.3)
plt.xticks(rotation=15)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Summary

# %%
print("="*70)
print("SUMMARY")
print("="*70)

print("\n📋 DATASET: MIMIC Perform AF")
print(f"   AF Patients: {len(af_files)}")
print(f"   Non-AF Patients: {len(nonaf_files)}")
print(f"   Sampling Rate: {SAMPLING_RATE} Hz")

print("\n📋 DATA SPLIT (sesuai jurnal):")
print(f"   Train: {len(train_af)+len(train_nonaf)} patients (65%)")
print(f"   Test: {len(test_af)+len(test_nonaf)} patients (35%)")

print("\n📋 METHODOLOGY (sesuai jurnal):")
print("   1. Feature Extraction: 5 statistical features")
print("   2. Transformer-based feature extraction (GridSearch, Optuna, Default)")
print("   3. XGBoost classifier (GridSearch, Optuna, Default)")

print("\n📊 RESULTS (XGBoost GridSearch + GS Transformer):")
print(f"   Accuracy : {acc_xgb*100:.2f}%")
print(f"   Precision: {prec_xgb*100:.2f}%")
print(f"   Recall   : {recall_xgb*100:.2f}%")
print(f"   F1 Score : {f1_xgb*100:.2f}%")
print(f"   ROC AUC  : {rocauc_xgb*100:.2f}%")

print("\n📊 RESULTS (XGBoost Optuna + Optuna Transformer):")
print(f"   Accuracy : {acc_optuna*100:.2f}%")
print(f"   Precision: {prec_optuna*100:.2f}%")
print(f"   Recall   : {recall_optuna*100:.2f}%")
print(f"   F1 Score : {f1_optuna*100:.2f}%")
print(f"   ROC AUC  : {roauc_optuna*100:.2f}%")

print("\n📊 RESULTS (XGBoost Default + Default Transformer):")
print(f"   Accuracy : {acc_default*100:.2f}%")
print(f"   Precision: {prec_default*100:.2f}%")
print(f"   Recall   : {recall_default*100:.2f}%")
print(f"   F1 Score : {f1_default*100:.2f}%")
print(f"   ROC AUC  : {rocauc_default*100:.2f}%")

print("\n" + "="*70)
# Out:
# ======================================================================
# SUMMARY
# ======================================================================
#
# 📋 DATASET: MIMIC Perform AF
#    AF Patients: 19
#    Non-AF Patients: 16
#    Sampling Rate: 125 Hz
#
# 📋 DATA SPLIT (sesuai jurnal):
#    Train: 22 patients (65%)
#    Test: 13 patients (35%)
#
# 📋 METHODOLOGY (sesuai jurnal):
#    1. Feature Extraction: 5 statistical features
#    2. Attention-based LSTM: 5 layers, nhidden=30
#    3. XGBoost: eta=0.2, nrounds=170, max_depth=12
#
# 📊 RESULTS:
#    Accuracy : 60.32%
#    Precision: 63.66%
#    Recall   : 61.22%
#    F1 Score : 62.41%
#    ROC AUC  : 63.72%
#
# ======================================================================
