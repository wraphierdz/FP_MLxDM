# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import glob
import os
from datetime import datetime as dt
from scipy.stats import skew, kurtosis
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (classification_report, confusion_matrix, ConfusionMatrixDisplay,
                             accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, roc_curve)
from sklearn.utils.class_weight import compute_class_weight
from xgboost import XGBClassifier
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Flatten, Layer
from tensorflow.keras import backend as K
from scikeras.wrappers import KerasClassifier
import optuna
from optuna.integration import TFKerasPruningCallback, XGBoostPruningCallback
import joblib
import warnings
warnings.filterwarnings('ignore')
from xgboost.callback import EarlyStopping
from tensorflow.keras.layers import LSTM
from sklearn.model_selection import KFold
from sklearn.svm import SVC


print("✅ Libraries imported successfully")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# ✅ Libraries imported successfully
# TensorFlow version: 2.20.0

# %% [markdown]
# # Load MIMIC Perform AF Dataset
#
# **Dataset info:**
# - AF: 16 pasien (mimic_perform_af_001 - mimic_perform_af_016)
# - Non-AF: 16 pasien (mimic_perform_non_af_001 - mimic_perform_non_af_016)
# - Sampling Rate: 125Hz
# - Duration: ~20 menit per pasien (150,000 samples)
# - Columns: Time, PPG, ECG, resp

# %%
# Path configuration
current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..', '..'))

af_folder = os.path.join(project_root, 'Data', 'af')
nonaf_folder = os.path.join(project_root, 'Data', 'non-af')

# List files - Balance: AF only up to patient 16
af_files_all = sorted(glob.glob(os.path.join(af_folder, '*_data.csv')))
af_files = af_files_all[:16]
nonaf_files = sorted(glob.glob(os.path.join(nonaf_folder, '*_data.csv')))

print("="*60)
print("DATASET: MIMIC Perform AF (Balanced)")
print("="*60)
print(f"\n📁 AF Folder: {af_folder}")
print(f"   Patients: {len(af_files)}")
print(f"\n📁 Non-AF Folder: {nonaf_folder}")
print(f"   Patients: {len(nonaf_files)}")
print(f"\n📊 Total Patients: {len(af_files) + len(nonaf_files)}")
# Out:
# ============================================================
# DATASET: MIMIC Perform AF (Balanced)
# ============================================================
#
# 📁 AF Folder: c:\Users\Lenovo\Documents\GitHub\FP_MLxDM\Data\af
#    Patients: 16
#
# 📁 Non-AF Folder: c:\Users\Lenovo\Documents\GitHub\FP_MLxDM\Data\non-af
#    Patients: 16
#
# 📊 Total Patients: 32

# %% [markdown]
# ## Train-Test Split (Sesuai Jurnal: 65% Train, 35% Test)
#
# Split berdasarkan pasien untuk menghindari data leakage

# %%
# Split 65% train, 35% test (sesuai jurnal)
# Split per kelas untuk menjaga proporsi

np.random.seed(42)

# Shuffle files
af_files_shuffled = np.random.permutation(af_files).tolist()
nonaf_files_shuffled = np.random.permutation(nonaf_files).tolist()

# Split AF: 65% train, 35% test
n_af_train = int(len(af_files) * 0.65)
train_af = af_files_shuffled[:n_af_train]
test_af = af_files_shuffled[n_af_train:]

# Split Non-AF: 65% train, 35% test
n_nonaf_train = int(len(nonaf_files) * 0.65)
train_nonaf = nonaf_files_shuffled[:n_nonaf_train]
test_nonaf = nonaf_files_shuffled[n_nonaf_train:]

print("="*60)
print("DATA SPLIT (Sesuai Jurnal: 65% Train, 35% Test)")
print("="*60)
print(f"\n📊 AF Split:")
print(f"   Train: {len(train_af)} patients")
print(f"   Test: {len(test_af)} patients")
print(f"\n📊 Non-AF Split:")
print(f"   Train: {len(train_nonaf)} patients")
print(f"   Test: {len(test_nonaf)} patients")
print(f"\n📊 Total:")
print(f"   Train: {len(train_af) + len(train_nonaf)} patients")
print(f"   Test: {len(test_af) + len(test_nonaf)} patients")
# Out:
# ============================================================
# DATA SPLIT (Sesuai Jurnal: 65% Train, 35% Test)
# ============================================================
#
# 📊 AF Split:
#    Train: 10 patients
#    Test: 6 patients
#
# 📊 Non-AF Split:
#    Train: 10 patients
#    Test: 6 patients
#
# 📊 Total:
#    Train: 20 patients
#    Test: 12 patients

# %% [markdown]
# ## Load Data Function

# %%
def load_patient_data(file_path, max_samples=150000):
    """
    Load ECG data dari file CSV.
    """
    df = pd.read_csv(file_path)
    
    # Limit samples
    if len(df) > max_samples:
        df = df.iloc[:max_samples]
    
    # Get ECG column
    ecg = df['ECG'].values
    
    # Handle NaN
    if np.any(np.isnan(ecg)):
        ecg = pd.Series(ecg).interpolate().values
    
    return ecg

print("✅ Load function defined")
# Out:
# ✅ Load function defined

# %% [markdown]
# ## Feature Extraction (Sesuai Jurnal)
#
# 5 fitur statistik per window:
# 1. Skewness
# 2. Kurtosis
# 3. Minimum
# 4. Maximum
# 5. Standard Deviation

# %%
# Parameters
SAMPLING_RATE = 125  # Hz
WINDOW_SIZE = SAMPLING_RATE  # 1 second = 125 samples
SEQUENCE_LENGTH = 10  # 10 windows = 10 seconds context

def extract_statistical_features(window):
    """
    Extract 5 statistical features (sesuai jurnal):
    Skewness, Kurtosis, Min, Max, STD
    """
    return np.array([
        skew(window),
        kurtosis(window),
        np.min(window),
        np.max(window),
        np.std(window)
    ])

def extract_features_from_signal(ecg_signal, window_size=125):
    """
    Extract features dari ECG signal.
    """
    n_windows = len(ecg_signal) // window_size
    features = []
    
    for i in range(n_windows):
        start = i * window_size
        end = start + window_size
        window = ecg_signal[start:end]
        features.append(extract_statistical_features(window))
    
    return np.array(features)

print(f"📊 Parameters:")
print(f"   Sampling Rate: {SAMPLING_RATE} Hz")
print(f"   Window Size: {WINDOW_SIZE} samples (1 second)")
print(f"   Sequence Length: {SEQUENCE_LENGTH} windows")
print(f"   Features: 5 (Skewness, Kurtosis, Min, Max, STD)")
# Out:
# 📊 Parameters:
#    Sampling Rate: 125 Hz
#    Window Size: 125 samples (1 second)
#    Sequence Length: 10 windows
#    Features: 5 (Skewness, Kurtosis, Min, Max, STD)

# %% [markdown]
# ## Load and Extract Features

# %%
def load_and_extract(files, label, desc=""):
    """
    Load files dan extract features.
    """
    all_features = []
    all_labels = []
    
    for f in files:
        patient_id = os.path.basename(f).replace('_data.csv', '')
        print(f"   Loading {patient_id}...", end=" ")
        
        # Load ECG
        ecg = load_patient_data(f)
        
        # Extract features
        features = extract_features_from_signal(ecg, WINDOW_SIZE)
        labels = np.full(len(features), label)
        
        all_features.append(features)
        all_labels.append(labels)
        
        print(f"{len(features)} windows")
    
    return np.vstack(all_features), np.concatenate(all_labels)

# Load Training Data
print("="*60)
print("LOADING TRAINING DATA")
print("="*60)

print("\n📥 Loading AF patients (Train)...")
X_train_af, y_train_af = load_and_extract(train_af, label=1)

print("\n📥 Loading Non-AF patients (Train)...")
X_train_nonaf, y_train_nonaf = load_and_extract(train_nonaf, label=0)

# Combine training data
X_train = np.vstack([X_train_af, X_train_nonaf])
y_train = np.concatenate([y_train_af, y_train_nonaf])

print("\n" + "="*60)
print("LOADING TEST DATA")
print("="*60)

print("\n📥 Loading AF patients (Test)...")
X_test_af, y_test_af = load_and_extract(test_af, label=1)

print("\n📥 Loading Non-AF patients (Test)...")
X_test_nonaf, y_test_nonaf = load_and_extract(test_nonaf, label=0)

# Combine test data
X_test = np.vstack([X_test_af, X_test_nonaf])
y_test = np.concatenate([y_test_af, y_test_nonaf])

print("\n" + "="*60)
print("✅ DATA LOADED")
print("="*60)
print(f"\n📊 Training Data:")
print(f"   Samples: {len(X_train)}")
print(f"   AF: {np.sum(y_train==1)} ({np.sum(y_train==1)/len(y_train)*100:.1f}%)")
print(f"   Non-AF: {np.sum(y_train==0)} ({np.sum(y_train==0)/len(y_train)*100:.1f}%)")
print(f"\n📊 Test Data:")
print(f"   Samples: {len(X_test)}")
print(f"   AF: {np.sum(y_test==1)} ({np.sum(y_test==1)/len(y_test)*100:.1f}%)")
print(f"   Non-AF: {np.sum(y_test==0)} ({np.sum(y_test==0)/len(y_test)*100:.1f}%)")
# Out:
# ============================================================
# LOADING TRAINING DATA
# ============================================================
#
# 📥 Loading AF patients (Train)...
#    Loading mimic_perform_af_001... 1200 windows
#    Loading mimic_perform_af_002... 1200 windows
#    Loading mimic_perform_af_006... 1200 windows
#    Loading mimic_perform_af_015... 1200 windows
#    Loading mimic_perform_af_014... 1200 windows
#    Loading mimic_perform_af_012... 1200 windows
#    Loading mimic_perform_af_009... 1200 windows
#    Loading mimic_perform_af_010... 1200 windows
#    Loading mimic_perform_af_003... 1200 windows
#    Loading mimic_perform_af_016... 1200 windows
#
# 📥 Loading Non-AF patients (Train)...
#    Loading mimic_perform_non_af_007... 1200 windows
#    Loading mimic_perform_non_af_003... 1200 windows
#    Loading mimic_perform_non_af_009... 1200 windows
#    Loading mimic_perform_non_af_014... 1200 windows
#    Loading mimic_perform_non_af_010... 1200 windows
#    Loading mimic_perform_non_af_013... 1200 windows
#    Loading mimic_perform_non_af_011... 1200 windows
#    Loading mimic_perform_non_af_004... 1200 windows
#    Loading mimic_perform_non_af_001... 1200 windows
#    Loading mimic_perform_non_af_016... 1200 windows
#
# ============================================================
# LOADING TEST DATA
# ============================================================
#
# 📥 Loading AF patients (Test)...
#    Loading mimic_perform_af_005... 1200 windows
#    Loading mimic_perform_af_008... 1200 windows
#    Loading mimic_perform_af_011... 1200 windows
#    Loading mimic_perform_af_013... 1200 windows
#    Loading mimic_perform_af_004... 1200 windows
#    Loading mimic_perform_af_007... 1200 windows
#
# 📥 Loading Non-AF patients (Test)...
#    Loading mimic_perform_non_af_015... 1200 windows
#    Loading mimic_perform_non_af_006... 1200 windows
#    Loading mimic_perform_non_af_012... 1200 windows
#    Loading mimic_perform_non_af_008... 1200 windows
#    Loading mimic_perform_non_af_002... 1200 windows
#    Loading mimic_perform_non_af_005... 1200 windows
#
# ============================================================
# ✅ DATA LOADED
# ============================================================
#
# 📊 Training Data:
#    Samples: 24000
#    AF: 12000 (50.0%)
#    Non-AF: 12000 (50.0%)
#
# 📊 Test Data:
#    Samples: 14400
#    AF: 7200 (50.0%)
#    Non-AF: 7200 (50.0%)

# %% [markdown]
# ## Preprocessing

# %%
# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("✅ Features normalized")
print(f"   Train shape: {X_train_scaled.shape}")
print(f"   Test shape: {X_test_scaled.shape}")
# Out:
# ✅ Features normalized
#    Train shape: (24000, 5)
#    Test shape: (14400, 5)

# %%
def create_sequences(data, labels, sequence_length=10):
    """
    Create sequences for LSTM.
    """
    X_seq = []
    y_seq = []
    
    for i in range(len(data) - sequence_length + 1):
        X_seq.append(data[i:i+sequence_length])
        y_seq.append(labels[i+sequence_length-1])
    
    return np.array(X_seq), np.array(y_seq)

# Create sequences
print(f"Creating sequences with {SEQUENCE_LENGTH} timesteps...")

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, SEQUENCE_LENGTH)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, SEQUENCE_LENGTH)

print(f"\n✅ Sequences created:")
print(f"   X_train: {X_train_seq.shape}")
print(f"   X_test: {X_test_seq.shape}")
# Out:
# Creating sequences with 10 timesteps...
#
# ✅ Sequences created:
#    X_train: (23991, 10, 5)
#    X_test: (14391, 10, 5)

# %% [markdown]
# # Transfomer Model

# %% [markdown]
# ### Grid Search

# %% [markdown]
# #### Model

# %%
def build_lstm_model(n_timesteps=SEQUENCE_LENGTH, n_features=5, lstm_units=64, dropout_rate=0.2):
    """
    Build LSTM model for Grid Search
    """
    inputs = Input(shape=(n_timesteps, n_features))
    x = LSTM(lstm_units, return_sequences=False)(inputs)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap model for scikit-learn
keras_clf = KerasClassifier(
    build_fn=build_lstm_model,
    n_timesteps=SEQUENCE_LENGTH,
    n_features=5,
    verbose=0
)

# Hyperparameter grid
param_grid = {
    'epochs': [20, 30],
    'batch_size': [32, 64],
    'model__lstm_units': [32, 64],
    'model__dropout_rate': [0.1, 0.2]
}

# Define GridSearchCV
grid = GridSearchCV(
    estimator=keras_clf, 
    param_grid=param_grid, 
    cv=3, 
    scoring='accuracy', 
    n_jobs=-1
)

print("✅ LSTM model and GridSearchCV defined")
print(f"   Total combinations: {len(param_grid['epochs']) * len(param_grid['batch_size']) * len(param_grid['model__lstm_units']) * len(param_grid['model__dropout_rate'])}")
# Out:
# ✅ LSTM model and GridSearchCV defined
#    Total combinations: 16

# %% [markdown]
# #### Running

# %%
# Compute class weights
class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
class_weight_dict = dict(enumerate(class_weights_array))

# Fit GridSearchCV
grid_result = grid.fit(X_train_seq, y_train_seq)

# %% [markdown]
# #### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'LSTM')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'SVM_LSTM_grid_{timestamp}.joblib')
best_lstm_model = grid_result.best_estimator_.model_
joblib.dump(best_lstm_model, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\LSTM\SVM_LSTM_grid_10122025_123141.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Grid Search

# %% [markdown]
# Score: 0.4919 (+/- 0.2191)
#
# Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__ff_dim': 64, 'model__num_heads': 4}

# %%
print("\n" + "="*60)
print("GRID SEARCH RESULTS")
print("="*60)
print(f"\n✅ Best Score: {grid_result.best_score_:.4f}")
print(f"\n📊 Best Hyperparameters:")
for param, value in grid_result.best_params_.items():
    print(f"   {param}: {value}")

print("\n📊 Top 5 Configurations:")
results_df = pd.DataFrame(grid_result.cv_results_)
results_df = results_df.sort_values('rank_test_score')
for idx, row in results_df.head(5).iterrows():
    print(f"\n   Rank {int(row['rank_test_score'])}:")
    print(f"      Score: {row['mean_test_score']:.4f} (+/- {row['std_test_score']:.4f})")
    print(f"      Params: {row['params']}")

# Visualize Grid Search Results
print("="*60)
print("GRID SEARCH RESULTS VISUALIZATION")
print("="*60)

# Create results dataframe
results_df = pd.DataFrame(grid_result.cv_results_)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Hyperparameter vs Score plots
params_to_plot = ['param_model__lstm_units', 'param_model__dropout_rate', 'param_batch_size', 'param_epochs']
titles = ['LSTM Units', 'Dropout Rate', 'Batch Size', 'Epochs']

for idx, (param, title) in enumerate(zip(params_to_plot, titles)):
    ax = axes[idx // 2, idx % 2]
    grouped = results_df.groupby(param)['mean_test_score'].mean()
    ax.bar(range(len(grouped)), grouped.values, color='steelblue', alpha=0.7)
    ax.set_xticks(range(len(grouped)))
    ax.set_xticklabels([str(x) for x in grouped.index])
    ax.set_xlabel(title)
    ax.set_ylabel('Mean CV Accuracy')
    ax.set_title(f'Effect of {title}')
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(MODEL_DIR, 'grid_search_results_lstm.png'), dpi=150, bbox_inches='tight')
plt.show()

print(f"\n✅ Best Configuration:")
print(f"   Accuracy: {grid_result.best_score_:.4f}")
for param, value in grid_result.best_params_.items():
    print(f"   {param}: {value}")
# Out:
# ============================================================
# GRID SEARCH RESULTS
# ============================================================
#
# ✅ Best Score: 0.2872
#
# 📊 Best Hyperparameters:
#    batch_size: 32
#    epochs: 20
#    model__dropout_rate: 0.2
#    model__lstm_units: 32
#
# 📊 Top 5 Configurations:
#
#    Rank 1:
#       Score: 0.2872 (+/- 0.1278)
#       Params: {'batch_size': 32, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__lstm_units': 32}
#
#    Rank 2:
#       Score: 0.2682 (+/- 0.1387)
#       Params: {'batch_size': 32, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__lstm_units': 64}
#
#    Rank 3:
#       Score: 0.2584 (+/- 0.1280)
#       Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.2, 'model__lstm_units': 64}
#
#    Rank 4:
#       Score: 0.2573 (+/- 0.1759)
#       Params: {'batch_size': 32, 'epochs': 20, 'model__dropout_rate': 0.1, 'model__lstm_units': 64}
#
#    Rank 5:
#       Score: 0.2562 (+/- 0.1316)
#       Params: {'batch_size': 64, 'epochs': 20, 'model__dropout_rate': 0.1, 'model__lstm_units': 64}
# ============================================================
# GRID SEARCH RESULTS VISUALIZATION
# ============================================================
# ✅ Best Configuration:
#    Accuracy: 0.2872
#    batch_size: 32
#    epochs: 20
#    model__dropout_rate: 0.2
#    model__lstm_units: 32

# %% [markdown]
# ### Extract Feature

# %%
# Extract features from best Grid Search Transformer model for XGBoost
best_transformer_model = grid_result.best_estimator_.model_

# Build feature extractor from the second-to-last layer
gs_feature_extractor = Model(
    inputs=best_transformer_model.inputs,
    outputs=best_transformer_model.layers[-2].output
)

# Extract features
print("Extracting features from Grid Search Transformer model...")
X_train_weights_gs = gs_feature_extractor.predict(X_train_seq, verbose=0)
X_test_weights_gs = gs_feature_extractor.predict(X_test_seq, verbose=0)

print("✅ Features extracted from Grid Search Transformer model")
print(f"   Train: {X_train_weights_gs.shape}")
print(f"   Test: {X_test_weights_gs.shape}")
# Out:
# Extracting features from Grid Search Transformer model...
# ✅ Features extracted from Grid Search Transformer model
#    Train: (23991, 32)
#    Test: (14391, 32)

# %% [markdown]
# ### Optuna

# %% [markdown]
# #### Model

# %%
def create_lstm_model_optuna(trial):
    """
    Create LSTM model with Optuna hyperparameters
    """
    # Hyperparameters to tune
    lstm_units = trial.suggest_categorical('lstm_units', [32, 64, 128])
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    ff_dim = trial.suggest_categorical('ff_dim', [32, 64, 128])

    # Build model
    inputs = Input(shape=(SEQUENCE_LENGTH, 5))
    x = LSTM(lstm_units, return_sequences=False)(inputs)
    x = Dropout(dropout_rate)(x)
    x = Dense(ff_dim, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

print("✅ LSTM model for Optuna defined")
# Out:
# ✅ LSTM model for Optuna defined

# %% [markdown]
# #### Running

# %%
def objective(trial):
    """
    Optuna objective function for LSTM hyperparameter tuning
    """
    # Hyperparameters to tune
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
    epochs = trial.suggest_int('epochs', 20, 50)
    
    # Create model
    model = create_lstm_model_optuna(trial)
    
    # Class weights
    class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
    class_weight_dict = dict(enumerate(class_weights_array))
    
    # Train model
    history = model.fit(
        X_train_seq, y_train_seq,
        batch_size=batch_size,
        epochs=epochs,
        class_weight=class_weight_dict,
        validation_split=0.2,
        verbose=0,
        callbacks=[TFKerasPruningCallback(trial, 'val_accuracy')]
    )
    
    return history.history['val_accuracy'][-1]

# Run Optuna optimization
print("="*60)
print("OPTUNA HYPERPARAMETER TUNING - LSTM")
print("="*60)
print("\nStarting Optuna optimization...")

study = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=30, show_progress_bar=True)

print("\n" + "="*60)
print("OPTUNA RESULTS")
print("="*60)
print(f"\n✅ Best Accuracy: {study.best_value:.4f}")
print(f"\n📊 Best Hyperparameters:")
for param, value in study.best_params.items():
    print(f"   {param}: {value}")
# Out:
# [I 2025-12-10 12:31:44,544] A new study created in memory with name: no-name-a054ccd4-f52e-4481-aadb-886522ffafb0
# ============================================================
# OPTUNA HYPERPARAMETER TUNING - LSTM
# ============================================================
#
# Starting Optuna optimization...
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-12-10 12:32:07,009] Trial 0 finished with value: 0.0006251302547752857 and parameters: {'batch_size': 128, 'epochs': 30, 'lstm_units': 32, 'dropout_rate': 0.4625093580142039, 'learning_rate': 0.0012482590881762834, 'ff_dim': 32}. Best is trial 0 with value: 0.0006251302547752857.
# [I 2025-12-10 12:33:58,994] Trial 1 finished with value: 0.0002083767467411235 and parameters: {'batch_size': 64, 'epochs': 46, 'lstm_units': 128, 'dropout_rate': 0.4219232974963205, 'learning_rate': 0.005531957541953517, 'ff_dim': 128}. Best is trial 0 with value: 0.0006251302547752857.
# [I 2025-12-10 12:35:45,082] Trial 2 finished with value: 0.0006251302547752857 and parameters: {'batch_size': 64, 'epochs': 41, 'lstm_units': 128, 'dropout_rate': 0.451432230334211, 'learning_rate': 0.00015618201943464814, 'ff_dim': 32}. Best is trial 0 with value: 0.0006251302547752857.
# [I 2025-12-10 12:36:22,128] Trial 3 finished with value: 0.0006251302547752857 and parameters: {'batch_size': 128, 'epochs': 37, 'lstm_units': 64, 'dropout_rate': 0.4126004187986786, 'learning_rate': 0.00029216463814675406, 'ff_dim': 32}. Best is trial 0 with value: 0.0006251302547752857.
# [I 2025-12-10 12:37:11,034] Trial 4 finished with value: 0.0010418837191537023 and parameters: {'batch_size': 32, 'epochs': 23, 'lstm_units': 64, 'dropout_rate': 0.11237371011118072, 'learning_rate': 0.005714533990383965, 'ff_dim': 32}. Best is trial 4 with value: 0.0010418837191537023.
# [I 2025-12-10 12:39:39,014] Trial 5 finished with value: 0.000416753493482247 and parameters: {'batch_size': 32, 'epochs': 43, 'lstm_units': 128, 'dropout_rate': 0.3926170927397331, 'learning_rate': 0.004325267387929803, 'ff_dim': 128}. Best is trial 4 with value: 0.0010418837191537023.
# [I 2025-12-10 12:39:43,660] Trial 6 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:39:52,362] Trial 7 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:39:57,359] Trial 8 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:01,284] Trial 9 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:07,123] Trial 10 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:23,416] Trial 11 finished with value: 0.0006251302547752857 and parameters: {'batch_size': 128, 'epochs': 22, 'lstm_units': 32, 'dropout_rate': 0.49383195343452935, 'learning_rate': 0.0006869443495533875, 'ff_dim': 32}. Best is trial 4 with value: 0.0010418837191537023.
# [I 2025-12-10 12:40:27,237] Trial 12 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:29,647] Trial 13 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:33,002] Trial 14 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:37,854] Trial 15 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:40,831] Trial 16 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:43,676] Trial 17 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:48,316] Trial 18 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:40:52,282] Trial 19 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:26,575] Trial 20 finished with value: 0.0006251302547752857 and parameters: {'batch_size': 128, 'epochs': 35, 'lstm_units': 32, 'dropout_rate': 0.26853469658010065, 'learning_rate': 0.00011634217395699373, 'ff_dim': 32}. Best is trial 4 with value: 0.0010418837191537023.
# [I 2025-12-10 12:41:30,445] Trial 21 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:35,234] Trial 22 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:40,012] Trial 23 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:43,868] Trial 24 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:47,916] Trial 25 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:53,615] Trial 26 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:41:59,353] Trial 27 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:42:04,296] Trial 28 pruned. Trial was pruned at epoch 0.
# [I 2025-12-10 12:42:07,288] Trial 29 pruned. Trial was pruned at epoch 0.
#
# ============================================================
# OPTUNA RESULTS
# ============================================================
#
# ✅ Best Accuracy: 0.0010
#
# 📊 Best Hyperparameters:
#    batch_size: 32
#    epochs: 23
#    lstm_units: 64
#    dropout_rate: 0.11237371011118072
#    learning_rate: 0.005714533990383965
#    ff_dim: 32

# %% [markdown]
# #### Save Model

# %%
# Save best Optuna LSTM model
os.makedirs('models/TRANSFORMER', exist_ok=True)
timestamp = dt.now().strftime('%d%m%Y_%H%M%S')

# Rebuild model with best params and retrain on full data
best_trial = study.best_trial
best_model = create_lstm_model_optuna(best_trial)

# Class weights
class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
class_weight_dict = dict(enumerate(class_weights_array))

# Retrain on full data
best_model.fit(
    X_train_seq, y_train_seq,
    batch_size=best_trial.params['batch_size'],
    epochs=best_trial.params['epochs'],
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9728 - loss: 0.0852
# Epoch 2/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9917 - loss: 0.0302
# Epoch 3/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9970 - loss: 0.0097
# Epoch 4/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9975 - loss: 0.0101
# Epoch 5/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9983 - loss: 0.0058
# Epoch 6/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9980 - loss: 0.0080
# Epoch 7/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9969 - loss: 0.0117
# Epoch 8/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9985 - loss: 0.0053
# Epoch 9/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9997 - loss: 0.0018
# Epoch 10/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0055
# Epoch 11/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9991 - loss: 0.0039
# Epoch 12/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9992 - loss: 0.0033
# Epoch 13/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 7.0442e-05
# Epoch 14/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9990 - loss: 0.0052
# Epoch 15/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 16/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 2.9404e-05
# Epoch 17/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 1.7234e-05
# Epoch 18/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 8.1708e-06
# Epoch 19/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 2.5463e-06
# Epoch 20/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 1.0000 - loss: 1.3106e-06
# Epoch 21/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 2.1252e-06
# Epoch 22/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9977 - loss: 0.0100
# Epoch 23/23
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9988 - loss: 0.0054

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'LSTM')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'SVM_LSTM_optuna_{timestamp}.joblib')

joblib.dump(best_model, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\LSTM\SVM_LSTM_optuna_10122025_124318.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Optuna

# %% [markdown]
# ✅ Best Optuna Configuration:
#   - Accuracy: 0.4968
#   - batch_size: 64
#   - epochs: 41
#   - num_heads: 8
#   - ff_dim: 128
#   - dropout_rate: 0.4037450941514691
#   - learning_rate: 0.00010064162612495603

# %%
# Visualisasi hasil Optuna Transformer

print("="*60)
print("OPTUNA RESULTS VISUALIZATION")
print("="*60)

# Plot optimization history
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.title("Optuna Optimization History (Validation Accuracy)")
plt.show()

# Plot parameter importance
optuna.visualization.matplotlib.plot_param_importances(study)
plt.title("Optuna Hyperparameter Importances")
plt.show()

# Print best trial summary
print(f"\n✅ Best Optuna Configuration:")
print(f"   Accuracy: {study.best_value:.4f}")
for param, value in study.best_params.items():
    print(f"   {param}: {value}")
# Out:
# ============================================================
# OPTUNA RESULTS VISUALIZATION
# ============================================================
# ✅ Best Optuna Configuration:
#    Accuracy: 0.0010
#    batch_size: 32
#    epochs: 23
#    lstm_units: 64
#    dropout_rate: 0.11237371011118072
#    learning_rate: 0.005714533990383965
#    ff_dim: 32

# %% [markdown]
# #### Extraxt Feature

# %%
# Extract features from best Optuna Transformer model for XGBoost
# Build feature extractor from the second-to-last layer
optuna_feature_extractor = Model(
    inputs=best_model.inputs,
    outputs=best_model.layers[-2].output
)

print("Extracting features from Optuna Transformer model...")
X_train_weights_optuna = optuna_feature_extractor.predict(X_train_seq, verbose=0)
X_test_weights_optuna = optuna_feature_extractor.predict(X_test_seq, verbose=0)

print("✅ Features extracted from Optuna Transformer model")
print(f"   Train: {X_train_weights_optuna.shape}")
print(f"   Test: {X_test_weights_optuna.shape}")
# Out:
# Extracting features from Optuna Transformer model...
# ✅ Features extracted from Optuna Transformer model
#    Train: (23991, 32)
#    Test: (14391, 32)

# %% [markdown]
# ### Default

# %% [markdown]
# #### Model

# %%
# Build default LSTM model
def build_lstm_model_default(n_timesteps=SEQUENCE_LENGTH, n_features=5, lstm_units=64, dropout_rate=0.2):
    """
    Build default LSTM model.
    """
    inputs = Input(shape=(n_timesteps, n_features))
    x = LSTM(lstm_units, return_sequences=False)(inputs)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

print("✅ Default LSTM model defined")
# Out:
# ✅ Default LSTM model defined

# %% [markdown]
# #### Training

# %%
# Build default LSTM model
model = build_lstm_model_default(
    n_timesteps=SEQUENCE_LENGTH,
    n_features=5,
    lstm_units=64,
    dropout_rate=0.2
)

print("Model Architecture:")
model.summary()

# Train model (tanpa validation - sesuai jurnal)
print("\nTraining Default LSTM Model...")

# Class weights untuk handle imbalance
class_weights_array = compute_class_weight('balanced', classes=np.unique(y_train_seq), y=y_train_seq)
class_weight_dict = dict(enumerate(class_weights_array))
print(f"Class weights: {class_weight_dict}")

history = model.fit(
    X_train_seq, y_train_seq,
    epochs=50,
    batch_size=64,
    class_weight=class_weight_dict,
    verbose=1
)

print(f"\n✅ Training completed.")
print(f"   Final accuracy: {history.history['accuracy'][-1]:.4f}")
# Out:
# Model Architecture:
# Model: "functional_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_32 (InputLayer)     │ (None, 10, 5)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_32 (LSTM)                  │ (None, 64)             │        17,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_63 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,985 (70.25 KB)
#  Trainable params: 17,985 (70.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Training Default LSTM Model...
# Class weights: {0: np.float64(0.999625), 1: np.float64(1.0003752814610958)}
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9417 - loss: 0.1474
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9928 - loss: 0.0263
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9959 - loss: 0.0156
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9977 - loss: 0.0099
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9981 - loss: 0.0073
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9965 - loss: 0.0111
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9984 - loss: 0.0049
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9985 - loss: 0.0047
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9989 - loss: 0.0037
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9993 - loss: 0.0027
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9994 - loss: 0.0022
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9995 - loss: 0.0017
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9995 - loss: 0.0017
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9995 - loss: 0.0019
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 5.3150e-04
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9994 - loss: 0.0018
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9986 - loss: 0.0046
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9997 - loss: 8.8922e-04
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9999 - loss: 4.2377e-04
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9999 - loss: 2.4608e-04
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9999 - loss: 4.2082e-04
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9999 - loss: 2.7623e-04
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.8093e-04
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9997 - loss: 0.0013
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9991 - loss: 0.0045
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.1768e-04
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.2047e-04
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9999 - loss: 3.9449e-04
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.9360e-04
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.5240e-04
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9999 - loss: 2.0618e-04
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 1.6947e-04
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.4314e-04
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9985 - loss: 0.0047
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9994 - loss: 0.0018
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9996 - loss: 9.6098e-04
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 1.0000 - loss: 2.4953e-04
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 1.0000 - loss: 1.0292e-04
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 1.0000 - loss: 1.1623e-04
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 5.5116e-05
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2794e-04
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.2487e-04
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 6.2189e-05
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 7.5473e-05
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 4.4751e-05
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.9357e-05
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 7.2915e-05
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 9.7798e-05
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 4.8599e-05
#
# ✅ Training completed.
#    Final accuracy: 1.0000

# %% [markdown]
# #### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'LSTM')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'SVM_LSTM_default_{timestamp}.joblib')

joblib.dump(model, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\LSTM\SVM_LSTM_default_10122025_124503.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Default

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Extract Features

# %%
transformer_default_feature_extractor = Model( # Ubah nama
    inputs=model.inputs, 
    outputs=model.layers[-2].output 
)

# Extract features
print("Extracting features from Transformer model...")
X_train_weights_default = transformer_default_feature_extractor.predict(X_train_seq, verbose=0) # Ubah nama
X_test_weights_default = transformer_default_feature_extractor.predict(X_test_seq, verbose=0)   # Ubah nama

print("✅ Features extracted from Transformer model")
print(f"   Train: {X_train_weights_default.shape}")
print(f"   Test: {X_test_weights_default.shape}")
# Out:
# Extracting features from Transformer model...
# ✅ Features extracted from Transformer model
#    Train: (23991, 64)
#    Test: (14391, 64)

# %% [markdown]
# # XGBoost Classifier

# %% [markdown]
# ### Grid search

# %% [markdown]
# #### Model

# %%
# Parameter grid untuk SVM
param_grid_svm = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

svm_clf = SVC(probability=True)

grid_svm = GridSearchCV(
    estimator=svm_clf,
    param_grid=param_grid_svm,
    scoring='accuracy',
    cv=3,
    n_jobs=-1,
    verbose=2
)

# %% [markdown]
# #### Running

# %%
print("Training SVM GridSearchCV with features from Grid Search Transformer...")
grid_svm.fit(X_train_weights_gs, y_train_seq)
print("✅ GridSearchCV completed")
print(f"Best params: {grid_svm.best_params_}")
print(f"Best score: {grid_svm.best_score_:.4f}")
# Out:
# Training SVM GridSearchCV with features from Grid Search Transformer...
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# ✅ GridSearchCV completed
# Best params: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Best score: 0.9999

# %% [markdown]
# #### Save Model

# %%
BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"

MODEL_DIR = os.path.join(BASE_DIR, 'models', 'SVM')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'svm_LSTM_grid_{timestamp}.joblib')

# Simpan model SVM hasil GridSearchCV
joblib.dump(grid_svm.best_estimator_, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\SVM\svm_LSTM_grid_10122025_124529.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Grid Search

# %%
# Best Score & Hyperparameters
print(f"\n✅ Best Accuracy: {grid_svm.best_score_:.4f}")
print(f"\n📊 Best Hyperparameters:")
for param, value in grid_svm.best_params_.items():
    print(f"   {param}: {value}")

# Top 5 Configurations
results_svm_df = pd.DataFrame(grid_svm.cv_results_).sort_values('rank_test_score')
print("\n📊 Top 5 Configurations:")
for idx, row in results_svm_df.head(5).iterrows():
    print(f"\n   Rank {int(row['rank_test_score'])}:")
    print(f"      Accuracy: {row['mean_test_score']:.4f} (+/- {row['std_test_score']:.4f})")
    print(f"      Params  : {row['params']}")

print("\n" + "="*60)
print("CONFUSION MATRIX & METRICS")
print("="*60)

# Metrics
y_pred_svm = grid_svm.predict(X_test_weights_gs)
y_prob_svm = grid_svm.predict_proba(X_test_weights_gs)[:, 1]
acc_svm = accuracy_score(y_test_seq, y_pred_svm)
prec_svm = precision_score(y_test_seq, y_pred_svm, zero_division=0)
recall_svm = recall_score(y_test_seq, y_pred_svm, zero_division=0)
f1_svm = f1_score(y_test_seq, y_pred_svm, zero_division=0)
rocauc_svm = roc_auc_score(y_test_seq, y_prob_svm) if len(np.unique(y_pred_svm)) > 1 else 0.5

print(f"\n✅ Performance Metrics:")
print(f"   Accuracy : {acc_svm:.4f} ({acc_svm*100:.2f}%)")
print(f"   Precision: {prec_svm:.4f} ({prec_svm*100:.2f}%)")
print(f"   Recall   : {recall_svm:.4f} ({recall_svm*100:.2f}%)")
print(f"   F1 Score : {f1_svm:.4f} ({f1_svm*100:.2f}%)")
print(f"   ROC AUC  : {rocauc_svm:.4f} ({rocauc_svm*100:.2f}%)")

# Confusion Matrix & ROC Curve side by side
cm_svm = confusion_matrix(y_test_seq, y_pred_svm)
fpr, tpr, thresholds = roc_curve(y_test_seq, y_prob_svm)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
disp_svm = ConfusionMatrixDisplay(confusion_matrix=cm_svm, display_labels=['Non-AF', 'AF'])
disp_svm.plot(cmap='Blues', ax=axes[0], colorbar=False)
axes[0].set_title('Confusion Matrix - SVM Grid Search')

# ROC Curve
axes[1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {rocauc_svm:.2f})')
axes[1].plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
axes[1].set_xlim([0.0, 1.0])
axes[1].set_ylim([0.0, 1.05])
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve - SVM Grid Search')
axes[1].legend(loc="lower right")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_test_seq, y_pred_svm, target_names=['Non-AF', 'AF'], zero_division=0))
# Out:
# ============================================================
# SVM GRID SEARCH RESULTS
# ============================================================
#
# ✅ Best Accuracy: 0.9999
#
# 📊 Best Hyperparameters:
#    C: 0.1
#    gamma: scale
#    kernel: linear
#
# 📊 Top 5 Configurations:
#
#    Rank 1:
#       Accuracy: 0.9999 (+/- 0.0001)
#       Params  : {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
#    Rank 1:
#       Accuracy: 0.9999 (+/- 0.0001)
#       Params  : {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
#
#    Rank 1:
#       Accuracy: 0.9999 (+/- 0.0001)
#       Params  : {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
#
#    Rank 1:
#       Accuracy: 0.9999 (+/- 0.0001)
#       Params  : {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#
#    Rank 1:
#       Accuracy: 0.9999 (+/- 0.0001)
#       Params  : {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#
# ============================================================
# CONFUSION MATRIX & METRICS
# ============================================================
#
# ✅ Performance Metrics:
#    Accuracy : 0.5144 (51.44%)
#    Precision: 0.5108 (51.08%)
#    Recall   : 0.6683 (66.83%)
#    F1 Score : 0.5790 (57.90%)
#    ROC AUC  : 0.5122 (51.22%)
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#       Non-AF       0.52      0.36      0.43      7200
#           AF       0.51      0.67      0.58      7191
#
#     accuracy                           0.51     14391
#    macro avg       0.52      0.51      0.50     14391
# weighted avg       0.52      0.51      0.50     14391

# %% [markdown]
# ### Optuna

# %% [markdown]
# #### Model

# %% [markdown]
# #### Running

# %%
# Optuna hyperparameter tuning for SVM (features from Optuna Transformer)
def objective_svm(trial):
    param = {
        'C': trial.suggest_categorical('C', [0.1, 1, 10]),
        'kernel': trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly']),
        'gamma': trial.suggest_categorical('gamma', ['scale', 'auto'])
    }
    svm = SVC(**param, probability=True)
    scores = []
    # 3-fold cross-validation
    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    for train_idx, val_idx in kf.split(X_train_weights_optuna):
        X_tr, X_val = X_train_weights_optuna[train_idx], X_train_weights_optuna[val_idx]
        y_tr, y_val = y_train_seq[train_idx], y_train_seq[val_idx]
        svm.fit(X_tr, y_tr)
        preds = svm.predict(X_val)
        scores.append(accuracy_score(y_val, preds))
    return np.mean(scores)

study_svm = optuna.create_study(direction='maximize')
study_svm.optimize(objective_svm, n_trials=30, show_progress_bar=True)

print("\n✅ Best SVM Optuna params:")
for k, v in study_svm.best_params.items():
    print(f"   {k}: {v}")
print(f"Best accuracy: {study_svm.best_value:.4f}")
# Out:
# [I 2025-12-10 12:50:07,992] A new study created in memory with name: no-name-61831f44-80f4-4803-92e0-4709882613a6
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-12-10 12:50:08,195] Trial 0 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:09,278] Trial 1 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:11,047] Trial 2 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:11,242] Trial 3 finished with value: 0.9999166354049436 and parameters: {'C': 1, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:12,260] Trial 4 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:12,526] Trial 5 finished with value: 0.999833270809887 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:13,221] Trial 6 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:13,358] Trial 7 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:13,518] Trial 8 finished with value: 0.9999166354049436 and parameters: {'C': 1, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:14,196] Trial 9 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:14,373] Trial 10 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:14,714] Trial 11 finished with value: 0.9997915885123588 and parameters: {'C': 0.1, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:14,961] Trial 12 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:16,165] Trial 13 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:16,906] Trial 14 finished with value: 0.9995414947271893 and parameters: {'C': 1, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:17,775] Trial 15 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:18,187] Trial 16 finished with value: 0.9997915885123588 and parameters: {'C': 0.1, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:19,568] Trial 17 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:19,880] Trial 18 finished with value: 0.999833270809887 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:20,097] Trial 19 finished with value: 0.9999166354049436 and parameters: {'C': 1, 'kernel': 'linear', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:20,321] Trial 20 finished with value: 0.9999166354049436 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:22,032] Trial 21 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:23,761] Trial 22 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:25,672] Trial 23 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:27,522] Trial 24 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:29,525] Trial 25 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:30,656] Trial 26 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:32,625] Trial 27 finished with value: 0.9999166354049436 and parameters: {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:32,813] Trial 28 finished with value: 0.9999166354049436 and parameters: {'C': 1, 'kernel': 'linear', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
# [I 2025-12-10 12:50:33,102] Trial 29 finished with value: 0.999833270809887 and parameters: {'C': 10, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 0 with value: 0.9999166354049436.
#
# ✅ Best SVM Optuna params:
#    C: 10
#    kernel: poly
#    gamma: auto
# Best accuracy: 0.9999

# %%
# Train SVM with Optuna best parameters using features from Optuna Transformer
svm_optuna = SVC(**study_svm.best_params, probability=True)

print("Training SVM with Optuna best parameters (Optuna Transformer features)...")
svm_optuna.fit(X_train_weights_optuna, y_train_seq)
print("✅ SVM (Optuna) trained")
# Out:
# Training SVM with Optuna best parameters (Optuna Transformer features)...
# ✅ SVM (Optuna) trained

# %% [markdown]
# ### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'SVM')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'svm_LSTM_optuna_{timestamp}.joblib')

joblib.dump(svm_optuna, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\SVM\svm_LSTM_optuna_10122025_125033.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Optuna

# %%
# Evaluate SVM Optuna model
y_prob_optuna = svm_optuna.predict_proba(X_test_weights_optuna)[:, 1]
y_pred_optuna = svm_optuna.predict(X_test_weights_optuna)

# Metrics
acc_optuna = accuracy_score(y_test_seq, y_pred_optuna)
prec_optuna = precision_score(y_test_seq, y_pred_optuna, zero_division=0)
recall_optuna = recall_score(y_test_seq, y_pred_optuna, zero_division=0)
f1_optuna = f1_score(y_test_seq, y_pred_optuna, zero_division=0)
roauc_optuna = roc_auc_score(y_test_seq, y_prob_optuna) if len(np.unique(y_pred_optuna)) > 1 else 0.5

print("="*60)
print("HYBRID MODEL EVALUATION (Optuna Transformer + SVM)")
print("Dataset: MIMIC Perform AF")
print("="*60)
print(f"\n📊 Performance Metrics:")
print(f"   Accuracy : {acc_optuna:.4f} ({acc_optuna*100:.2f}%)")
print(f"   Precision: {prec_optuna:.4f} ({prec_optuna*100:.2f}%)")
print(f"   Recall   : {recall_optuna:.4f} ({recall_optuna*100:.2f}%)")
print(f"   F1 Score : {f1_optuna:.4f} ({f1_optuna*100:.2f}%)")
print(f"   ROC AUC  : {roauc_optuna:.4f} ({roauc_optuna*100:.2f}%)")

# Confusion Matrix & ROC Curve
cm_optuna = confusion_matrix(y_test_seq, y_pred_optuna)
fpr, tpr, thresholds = roc_curve(y_test_seq, y_prob_optuna)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
disp_optuna = ConfusionMatrixDisplay(confusion_matrix=cm_optuna, display_labels=['Non-AF', 'AF'])
disp_optuna.plot(cmap='Blues', ax=axes[0], colorbar=False)
axes[0].set_title('Confusion Matrix - SVM Optuna')

# ROC Curve
axes[1].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roauc_optuna:.2f})')
axes[1].plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
axes[1].set_xlim([0.0, 1.0])
axes[1].set_ylim([0.0, 1.05])
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve')
axes[1].legend(loc="lower right")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("Classification Report:")
print("="*60)
print(classification_report(y_test_seq, y_pred_optuna, target_names=['Non-AF', 'AF'], zero_division=0))
# Out:
# ============================================================
# HYBRID MODEL EVALUATION (Optuna Transformer + SVM)
# Dataset: MIMIC Perform AF
# ============================================================
#
# 📊 Performance Metrics:
#    Accuracy : 0.5146 (51.46%)
#    Precision: 0.5104 (51.04%)
#    Recall   : 0.7020 (70.20%)
#    F1 Score : 0.5911 (59.11%)
#    ROC AUC  : 0.4999 (49.99%)
# ============================================================
# Classification Report:
# ============================================================
#               precision    recall  f1-score   support
#
#       Non-AF       0.52      0.33      0.40      7200
#           AF       0.51      0.70      0.59      7191
#
#     accuracy                           0.51     14391
#    macro avg       0.52      0.51      0.50     14391
# weighted avg       0.52      0.51      0.50     14391

# %% [markdown]
# ### Default

# %% [markdown]
# #### Model

# %%
xgb_default = SVC(probability=True)

# %% [markdown]
# #### Running

# %%
print("Training SVM Default (fitur ekstraksi default)...")
xgb_default.fit(X_train_weights_default, y_train_seq)
print("✅ SVM Default trained")
# Out:
# Training SVM Default (fitur ekstraksi default)...
# ✅ SVM Default trained

# %% [markdown]
# #### Save Model

# %%
import joblib
import os
from datetime import datetime as dt

BASE_DIR = r"C:\Users\Lenovo\Documents\GitHub\FP_MLxDM"
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'SVM')
os.makedirs(MODEL_DIR, exist_ok=True)

timestamp = dt.now().strftime('%d%m%Y_%H%M%S')
file_path = os.path.join(MODEL_DIR, f'svm_LSTM_default_{timestamp}.joblib')

joblib.dump(xgb_default, file_path)

print(f"✅ Model tersimpan di jalur ABSOLUT:")
print(f"   {file_path}")

# Verifikasi keberadaan berkas secara instan
if os.path.exists(file_path):
    print("✅ Verifikasi: Berkas ditemukan di disk.")
else:
    print("❌ Verifikasi: Gagal menemukan berkas di jalur absolut yang ditentukan.")
# Out:
# ✅ Model tersimpan di jalur ABSOLUT:
#    C:\Users\Lenovo\Documents\GitHub\FP_MLxDM\models\SVM\svm_LSTM_default_10122025_125034.joblib
# ✅ Verifikasi: Berkas ditemukan di disk.

# %% [markdown]
# #### Hasil Default

# %%
y_prob_default = xgb_default.predict_proba(X_test_weights_default)[:, 1]
y_pred_default = xgb_default.predict(X_test_weights_default)

# Metrics
acc_default = accuracy_score(y_test_seq, y_pred_default)
prec_default = precision_score(y_test_seq, y_pred_default, zero_division=0)
recall_default = recall_score(y_test_seq, y_pred_default, zero_division=0)
f1_default = f1_score(y_test_seq, y_pred_default, zero_division=0)
rocauc_default = roc_auc_score(y_test_seq, y_prob_default) if len(np.unique(y_pred_default)) > 1 else 0.5

print("="*60)
print("HYBRID MODEL EVALUATION (Default Transformer + SVM)")
print("Dataset: MIMIC Perform AF")
print("="*60)
print(f"\n📊 Performance Metrics:")
print(f"   Accuracy : {acc_default:.4f} ({acc_default*100:.2f}%)")
print(f"   Precision: {prec_default:.4f} ({prec_default*100:.2f}%)")
print(f"   Recall   : {recall_default:.4f} ({recall_default*100:.2f}%)")
print(f"   F1 Score : {f1_default:.4f} ({f1_default*100:.2f}%)")
print(f"   ROC AUC  : {rocauc_default:.4f} ({rocauc_default*100:.2f}%)")

# Confusion Matrix & ROC Curve side by side
cm_default = confusion_matrix(y_test_seq, y_pred_default)
fpr, tpr, thresholds = roc_curve(y_test_seq, y_prob_default)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
disp_default = ConfusionMatrixDisplay(confusion_matrix=cm_default, display_labels=['Non-AF', 'AF'])
disp_default.plot(cmap='Blues', ax=axes[0], colorbar=False)
axes[0].set_title('Confusion Matrix - SVM Default')

# ROC Curve
axes[1].plot(fpr, tpr, label=f'ROC curve (AUC = {rocauc_default:.2f})', color='darkorange')
axes[1].plot([0, 1], [0, 1], 'k--', lw=1)
axes[1].set_xlim([0.0, 1.0])
axes[1].set_ylim([0.0, 1.05])
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve - SVM Default')
axes[1].legend(loc="lower right")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\n" + "="*60)
print("Classification Report:")
print("="*60)
print(classification_report(y_test_seq, y_pred_default, target_names=['Non-AF', 'AF'], zero_division=0))
# Out:
# ============================================================
# HYBRID MODEL EVALUATION (Default Transformer + SVM)
# Dataset: MIMIC Perform AF
# ============================================================
#
# 📊 Performance Metrics:
#    Accuracy : 0.5169 (51.69%)
#    Precision: 0.5129 (51.29%)
#    Recall   : 0.6617 (66.17%)
#    F1 Score : 0.5778 (57.78%)
#    ROC AUC  : 0.5133 (51.33%)
# ============================================================
# Classification Report:
# ============================================================
#               precision    recall  f1-score   support
#
#       Non-AF       0.52      0.37      0.44      7200
#           AF       0.51      0.66      0.58      7191
#
#     accuracy                           0.52     14391
#    macro avg       0.52      0.52      0.51     14391
# weighted avg       0.52      0.52      0.51     14391

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Perbandingan Metrics

# %%
metrics_df = pd.DataFrame({
    'Model': [
        'SVM GridSearch (GS Transformer)', 
        'SVM Optuna (Optuna Transformer)', 
        'SVM Default (Default Transformer)'
    ],
    'Accuracy': [
        acc_svm, 
        acc_optuna, 
        acc_default
    ],
    'Precision': [
        prec_svm, 
        prec_optuna, 
        prec_default
    ],
    'Recall': [
        recall_svm, 
        recall_optuna, 
        recall_default
    ],
    'F1 Score': [
        f1_svm, 
        f1_optuna, 
        f1_default
    ],
    'ROC AUC': [
        rocauc_svm, 
        roauc_optuna, 
        rocauc_default
    ]
})

metrics_plot = metrics_df.set_index('Model')
metrics_plot.plot(kind='bar', figsize=(12, 6))
plt.title('Perbandingan Semua Metric SVM (Transformer Features)')
plt.ylabel('Score')
plt.ylim(0, 1)
plt.grid(axis='y', alpha=0.3)
plt.xticks(rotation=15)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Summary

# %%
print("="*70)
print("SUMMARY")
print("="*70)

print("\n📋 DATASET: MIMIC Perform AF")
print(f"   AF Patients: {len(af_files)}")
print(f"   Non-AF Patients: {len(nonaf_files)}")
print(f"   Sampling Rate: {SAMPLING_RATE} Hz")

print("\n📋 DATA SPLIT (sesuai jurnal):")
print(f"   Train: {len(train_af)+len(train_nonaf)} patients (65%)")
print(f"   Test: {len(test_af)+len(test_nonaf)} patients (35%)")

print("\n📋 METHODOLOGY (sesuai jurnal):")
print("   1. Feature Extraction: 5 statistical features")
print("   2. Transformer-based feature extraction (GridSearch, Optuna, Default)")
print("   3. SVM classifier (GridSearch, Optuna, Default)")

print("\n📊 RESULTS (SVM GridSearch + GS Transformer):")
print(f"   Accuracy : {acc_svm*100:.2f}%")
print(f"   Precision: {prec_svm*100:.2f}%")
print(f"   Recall   : {recall_svm*100:.2f}%")
print(f"   F1 Score : {f1_svm*100:.2f}%")
print(f"   ROC AUC  : {rocauc_svm*100:.2f}%")

print("\n📊 RESULTS (SVM Optuna + Optuna Transformer):")
print(f"   Accuracy : {acc_optuna*100:.2f}%")
print(f"   Precision: {prec_optuna*100:.2f}%")
print(f"   Recall   : {recall_optuna*100:.2f}%")
print(f"   F1 Score : {f1_optuna*100:.2f}%")
print(f"   ROC AUC  : {roauc_optuna*100:.2f}%")

print("\n📊 RESULTS (SVM Default + Default Transformer):")
print(f"   Accuracy : {acc_default*100:.2f}%")
print(f"   Precision: {prec_default*100:.2f}%")
print(f"   Recall   : {recall_default*100:.2f}%")
print(f"   F1 Score : {f1_default*100:.2f}%")
print(f"   ROC AUC  : {rocauc_default*100:.2f}%")

print("\n" + "="*70)
# Out:
# ======================================================================
# SUMMARY
# ======================================================================
#
# 📋 DATASET: MIMIC Perform AF
#    AF Patients: 16
#    Non-AF Patients: 16
#    Sampling Rate: 125 Hz
#
# 📋 DATA SPLIT (sesuai jurnal):
#    Train: 20 patients (65%)
#    Test: 12 patients (35%)
#
# 📋 METHODOLOGY (sesuai jurnal):
#    1. Feature Extraction: 5 statistical features
#    2. Transformer-based feature extraction (GridSearch, Optuna, Default)
#    3. SVM classifier (GridSearch, Optuna, Default)
#
# 📊 RESULTS (SVM GridSearch + GS Transformer):
#    Accuracy : 51.44%
#    Precision: 51.08%
#    Recall   : 66.83%
#    F1 Score : 57.90%
#    ROC AUC  : 51.22%
#
# 📊 RESULTS (SVM Optuna + Optuna Transformer):
#    Accuracy : 51.46%
#    Precision: 51.04%
#    Recall   : 70.20%
#    F1 Score : 59.11%
#    ROC AUC  : 49.99%
#
# 📊 RESULTS (SVM Default + Default Transformer):
#    Accuracy : 51.69%
#    Precision: 51.29%
#    Recall   : 66.17%
#    F1 Score : 57.78%
#    ROC AUC  : 51.33%
#
# ======================================================================
